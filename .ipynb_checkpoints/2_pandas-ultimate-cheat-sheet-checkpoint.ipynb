# %%
### 1. Import & Setup

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Import & Setup | import pandas | Standard import with alias | `import pandas as pd` |
| Import & Setup | import numpy | Usually imported alongside pandas | `import numpy as np` |
| Import & Setup | check version | Get installed pandas version | `pd.__version__` |
| Import & Setup | set display max rows | Control how many rows print | `pd.set_option("display.max_rows", 100)` |
| Import & Setup | set display max columns | Control how many columns print | `pd.set_option("display.max_columns", 50)` |
| Import & Setup | set display width | Control console output width | `pd.set_option("display.width", 200)` |
| Import & Setup | set float precision | Limit decimal places shown | `pd.set_option("display.float_format", "{:.2f}".format)` |
| Import & Setup | reset option | Revert a setting to default | `pd.reset_option("display.max_rows")` |
| Import & Setup | get option | Read current option value | `pd.get_option("display.max_columns")` |
| Import & Setup | describe options | List all available options | `pd.describe_option()` |
| Import & Setup | option context | Temporarily set options in a block | `with pd.option_context("display.max_rows", 10): ...` |
| Import & Setup | copy on write | Enable copy-on-write (pandas 2.0+) | `pd.options.mode.copy_on_write = True` |

### 2. Data Creation

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Data Creation | pd.Series from list | 1D labeled array from a list | `s = pd.Series([1, 2, 3], index=["a", "b", "c"])` |
| Data Creation | pd.Series from dict | Series from a dictionary | `s = pd.Series({"a": 1, "b": 2})` |
| Data Creation | pd.Series from scalar | Broadcast scalar to all index positions | `s = pd.Series(5, index=["a", "b", "c"])` |
| Data Creation | pd.DataFrame from dict | 2D table from dict of lists/arrays | `df = pd.DataFrame({"A": [1, 2], "B": [3, 4]})` |
| Data Creation | pd.DataFrame from dict of Series | Each Series becomes a column | `df = pd.DataFrame({"A": pd.Series([1, 2]), "B": pd.Series([3, 4])})` |
| Data Creation | pd.DataFrame from list of dicts | Each dict is a row | `df = pd.DataFrame([{"A": 1, "B": 2}, {"A": 3, "B": 4}])` |
| Data Creation | pd.DataFrame from numpy | 2D array with optional index/columns | `df = pd.DataFrame(np.random.rand(3, 2), columns=["A", "B"])` |
| Data Creation | pd.DataFrame from records | Structured array or list of tuples | `df = pd.DataFrame.from_records([(1, 2), (3, 4)], columns=["A", "B"])` |
| Data Creation | pd.DataFrame from dict items | Orient dict items as rows | `df = pd.DataFrame.from_dict({"r1": {"A": 1}, "r2": {"A": 2}}, orient="index")` |
| Data Creation | pd.date_range | Generate datetime index | `idx = pd.date_range("2024-01-01", periods=5, freq="D")` |
| Data Creation | pd.timedelta_range | Generate timedelta index | `td = pd.timedelta_range("1 day", periods=3)` |
| Data Creation | pd.interval_range | Generate interval index | `ii = pd.interval_range(start=0, end=5)` |
| Data Creation | pd.Categorical | Create categorical data | `cat = pd.Categorical(["a", "b", "a"], categories=["a", "b", "c"])` |
| Data Creation | pd.NA | pandas scalar missing value | `pd.NA` |
| Data Creation | pd.NaT | Not-a-Time for datetime | `pd.NaT` |
| Data Creation | pd.isna | Check for NA values | `pd.isna([1, None, 3])` |
| Data Creation | pd.notna | Check for non-NA values | `pd.notna([1, None, 3])` |

### 3. I/O — Reading Data

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| I/O Read | read_csv | Read comma-separated values | `df = pd.read_csv("file.csv", header=0, index_col=0)` |
| I/O Read | read_csv with dtype | Specify column types on read | `df = pd.read_csv("file.csv", dtype={"id": "int32"})` |
| I/O Read | read_csv parse dates | Parse columns as datetime on read | `df = pd.read_csv("file.csv", parse_dates=["date"])` |
| I/O Read | read_csv pyarrow backend | Use PyArrow for I/O and dtypes | `df = pd.read_csv("file.csv", dtype_backend="pyarrow", engine="pyarrow")` |
| I/O Read | read_excel | Read Excel file (.xlsx/.xls) | `df = pd.read_excel("file.xlsx", sheet_name="Sheet1")` |
| I/O Read | read_sql | Read SQL query or table | `df = pd.read_sql("SELECT * FROM t", conn)` |
| I/O Read | read_sql_table | Read entire SQL table | `df = pd.read_sql_table("employees", conn)` |
| I/O Read | read_json | Read JSON string or file | `df = pd.read_json("file.json", orient="records")` |
| I/O Read | read_parquet | Read Apache Parquet file | `df = pd.read_parquet("file.parquet")` |
| I/O Read | read_feather | Read Feather format | `df = pd.read_feather("file.feather")` |
| I/O Read | read_orc | Read ORC format | `df = pd.read_orc("file.orc")` |
| I/O Read | read_html | Read HTML tables from URL or file | `dfs = pd.read_html("https://example.com/table.html")` |
| I/O Read | read_clipboard | Read data from system clipboard | `df = pd.read_clipboard()` |
| I/O Read | read_pickle | Read pickled pandas object | `df = pd.read_pickle("file.pkl")` |
| I/O Read | read_sas | Read SAS file | `df = pd.read_sas("file.sas7bdat")` |
| I/O Read | read_stata | Read Stata file | `df = pd.read_stata("file.dta")` |
| I/O Read | read_hdf | Read HDF5 store | `df = pd.read_hdf("store.h5", key="df")` |

### 4. I/O — Writing Data

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| I/O Write | to_csv | Write DataFrame to CSV | `df.to_csv("out.csv", index=False)` |
| I/O Write | to_csv with sep | Use custom delimiter | `df.to_csv("out.tsv", sep="\t", index=False)` |
| I/O Write | to_excel | Write to Excel file | `df.to_excel("out.xlsx", sheet_name="Data")` |
| I/O Write | to_sql | Write to SQL database | `df.to_sql("table_name", conn, if_exists="replace")` |
| I/O Write | to_json | Write to JSON | `df.to_json("out.json", orient="records")` |
| I/O Write | to_parquet | Write to Parquet | `df.to_parquet("out.parquet")` |
| I/O Write | to_feather | Write to Feather | `df.to_feather("out.feather")` |
| I/O Write | to_orc | Write to ORC | `df.to_orc("out.orc")` |
| I/O Write | to_html | Write to HTML table | `df.to_html("out.html", index=False)` |
| I/O Write | to_clipboard | Copy to system clipboard | `df.to_clipboard(index=False)` |
| I/O Write | to_pickle | Pickle the DataFrame | `df.to_pickle("out.pkl")` |
| I/O Write | to_hdf | Write to HDF5 store | `df.to_hdf("store.h5", key="df")` |
| I/O Write | to_markdown | Write to markdown table | `df.to_markdown("out.md")` |
| I/O Write | to_dict | Convert to dictionary | `df.to_dict(orient="records")` |
| I/O Write | to_records | Convert to numpy recarray | `df.to_records()` |
| I/O Write | to_numpy | Convert to numpy array | `df.to_numpy()` |
| I/O Write | to_string | Render as string | `df.to_string(index=False)` |
| I/O Write | to_latex | Render as LaTeX table | `df.to_latex(index=False)` |
| I/O Write | to_xml | Write to XML | `df.to_xml("out.xml")` |
| I/O Write | to_stata | Write to Stata format | `df.to_stata("out.dta")` |

### 5. Inspection & Attributes

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Inspection | head | First N rows preview | `df.head(5)` |
| Inspection | tail | Last N rows preview | `df.tail(5)` |
| Inspection | info | Column types, non-null counts, memory | `df.info()` |
| Inspection | info with memory | Detailed memory breakdown | `df.info(memory_usage="deep")` |
| Inspection | describe | Summary stats for numeric columns | `df.describe()` |
| Inspection | describe all | Include all dtypes | `df.describe(include="all")` |
| Inspection | shape | Rows × columns tuple | `df.shape` |
| Inspection | dtypes | Data type of each column | `df.dtypes` |
| Inspection | columns | Column labels Index object | `df.columns` |
| Inspection | index | Row index object | `df.index` |
| Inspection | values | Underlying numpy array | `df.values` |
| Inspection | empty | Check if DataFrame is empty | `df.empty` |
| Inspection | ndim | Number of dimensions (2 for DF) | `df.ndim` |
| Inspection | size | Total number of elements | `df.size` |
| Inspection | memory_usage | Memory per column in bytes | `df.memory_usage(deep=True)` |
| Inspection | T | Transpose rows and columns | `df.T` |

### 6. Selection & Indexing

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Selection | [] single column | Select one column as Series | `df["col"]` |
| Selection | [] multiple columns | Select subset as DataFrame | `df[["col1", "col2"]]` |
| Selection | [] row slice | Slice rows by position (integer) | `df[0:5]` |
| Selection | [] boolean mask | Filter rows by condition | `df[df["age"] > 30]` |
| Selection | loc label | Label-based selection | `df.loc[0:5, ["col1", "col2"]]` |
| Selection | loc scalar | Single cell by label | `df.loc[0, "col"]` |
| Selection | loc slice | Slice by label (inclusive) | `df.loc["a":"c", :]` |
| Selection | loc boolean | Boolean mask with loc | `df.loc[df["age"] > 30, :]` |
| Selection | loc assignment | Set values by label | `df.loc[0, "col"] = 99` |
| Selection | loc set multiple | Set multiple cells | `df.loc[df["age"] > 30, "status"] = "senior"` |
| Selection | iloc position | Position-based selection | `df.iloc[0:5, 0:3]` |
| Selection | iloc scalar | Single cell by position | `df.iloc[0, 1]` |
| Selection | iloc list | Select by list of positions | `df.iloc[[0, 2, 4], [1, 3]]` |
| Selection | iloc negative | Negative indexing | `df.iloc[-5:]` |
| Selection | at | Fast scalar access by label | `df.at[0, "col"]` |
| Selection | iat | Fast scalar access by position | `df.iat[0, 1]` |
| Selection | isin | Check membership in a set | `df[df["dept"].isin(["IT", "HR"])]` |
| Selection | between | Check if values in range | `df[df["age"].between(20, 30)]` |
| Selection | where | Replace where condition is False | `df.where(df > 0, 0)` |
| Selection | mask | Replace where condition is True | `df.mask(df < 0, 0)` |
| Selection | query | SQL-like expression filter | `df.query("age > 30 and dept == 'IT'")` |
| Selection | query with variable | Use external variable in query | `df.query("age > @threshold")` |
| Selection | filter | Subset columns/rows by label regex | `df.filter(like="salary")` |
| Selection | filter regex | Columns matching regex | `df.filter(regex="^salary_.*")` |
| Selection | get | Dict-like get with default | `df.get("col", default=pd.Series())` |
| Selection | first | First rows by date offset | `df.first("3D")` |
| Selection | last | Last rows by date offset | `df.last("3D")` |
| Selection | take | Take elements along axis by positions | `df.take([0, 2, 4])` |
| Selection | xs | Cross-section from MultiIndex | `df.xs("IT", level="dept")` |
| Selection | pop | Remove column and return it | `col = df.pop("temp_col")` |

### 7. Filtering & Conditional Logic

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Filtering | single condition | Rows where condition is True | `df[df["age"] > 30]` |
| Filtering | multiple AND | Combine with & | `df[(df["age"] > 30) & (df["salary"] > 50000)]` |
| Filtering | multiple OR | Combine with | | `df[(df["dept"] == "IT") | (df["dept"] == "HR")]` |
| Filtering | NOT condition | Negate with ~ | `df[~(df["age"] > 30)]` |
| Filtering | isnull / isna | Check for missing values | `df[df["col"].isna()]` |
| Filtering | notnull / notna | Check for non-missing | `df[df["col"].notna()]` |
| Filtering | str.contains | String contains substring | `df[df["name"].str.contains("John", na=False)]` |
| Filtering | str.startswith | String starts with prefix | `df[df["name"].str.startswith("J")]` |
| Filtering | str.endswith | String ends with suffix | `df[df["name"].str.endswith("son")]` |
| Filtering | str.match | Regex match at start | `df[df["name"].str.match(r"^A.*")]` |
| Filtering | dt accessor | Filter by date parts | `df[df["date"].dt.year == 2024]` |
| Filtering | isin with negation | Not in a list | `df[~df["dept"].isin(["IT", "HR"])]` |
| Filtering | conditional assignment | Assign based on condition | `df.loc[df["age"] > 30, "group"] = "senior"` |
| Filtering | np.where | Vectorized if-else | `df["flag"] = np.where(df["age"] > 30, "old", "young")` |
| Filtering | assign | Add column without modifying original | `df.assign(bonus=df["salary"] * 0.1)` |

### 8. Adding, Updating & Deleting

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Modify | add new column | Create column from expression | `df["bonus"] = df["salary"] * 0.1` |
| Modify | add column from Series | Align by index | `df["new"] = pd.Series([1, 2, 3])` |
| Modify | insert column | Insert at specific position | `df.insert(1, "mid_col", [10, 20, 30])` |
| Modify | rename columns | Rename specific columns | `df.rename(columns={"old": "new"})` |
| Modify | rename index | Rename row labels | `df.rename(index={0: "first"})` |
| Modify | set index | Use column as row index | `df.set_index("id", inplace=True)` |
| Modify | reset index | Move index back to column | `df.reset_index(drop=True, inplace=True)` |
| Modify | drop column | Remove one or more columns | `df.drop("col", axis=1)` |
| Modify | drop columns list | Remove multiple columns | `df.drop(["a", "b"], axis=1)` |
| Modify | drop row | Remove row by label | `df.drop(0, axis=0)` |
| Modify | drop rows list | Remove multiple rows | `df.drop([0, 2], axis=0)` |
| Modify | drop by index position | Remove by position | `df.drop(df.index[0])` |
| Modify | update values | Modify in place with dict/Series | `df.update(other_df)` |
| Modify | replace values | Replace specific values | `df.replace({"old": "new", 0: np.nan})` |
| Modify | replace regex | Replace by regex pattern | `df["col"].replace(r"\$", "", regex=True)` |

### 9. Sorting

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Sorting | sort_values | Sort by column values | `df.sort_values("salary", ascending=False)` |
| Sorting | sort_values multi | Sort by multiple columns | `df.sort_values(["dept", "salary"], ascending=[True, False])` |
| Sorting | sort_values key | Custom sort key function | `df.sort_values("name", key=lambda x: x.str.lower())` |
| Sorting | sort_index | Sort by row index | `df.sort_index(ascending=True)` |
| Sorting | sort_index axis | Sort columns by label | `df.sort_index(axis=1)` |
| Sorting | nlargest | Top N rows by column | `df.nlargest(5, "salary")` |
| Sorting | nsmallest | Bottom N rows by column | `df.nsmallest(5, "salary")` |
| Sorting | rank | Rank values within column | `df["rank"] = df["salary"].rank(ascending=False)` |

### 10. Missing Data

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Missing Data | isna / isnull | Detect missing values | `df.isna()` |
| Missing Data | notna / notnull | Detect non-missing values | `df.notna()` |
| Missing Data | isna sum | Count missing per column | `df.isna().sum()` |
| Missing Data | isna mean | Proportion missing per column | `df.isna().mean()` |
| Missing Data | dropna | Drop rows with any NA | `df.dropna()` |
| Missing Data | dropna all | Drop rows where all are NA | `df.dropna(how="all")` |
| Missing Data | dropna thresh | Keep rows with at least N non-NA | `df.dropna(thresh=3)` |
| Missing Data | dropna subset | Drop only in specific columns | `df.dropna(subset=["col1", "col2"])` |
| Missing Data | dropna axis | Drop columns with any NA | `df.dropna(axis=1)` |
| Missing Data | fillna scalar | Fill all NA with a value | `df.fillna(0)` |
| Missing Data | fillna dict | Fill per-column defaults | `df.fillna({"A": 0, "B": "unknown"})` |
| Missing Data | fillna method | Forward/backward fill | `df.fillna(method="ffill")` or `df.ffill()` |
| Missing Data | fillna limit | Limit consecutive fills | `df.fillna(method="ffill", limit=1)` |
| Missing Data | interpolate | Linear interpolation | `df.interpolate(method="linear")` |
| Missing Data | interpolate time | Time-based interpolation | `df.interpolate(method="time")` |
| Missing Data | replace NA | Replace specific NA-like values | `df.replace("?", pd.NA)` |
| Missing Data | bfill | Backward fill | `df.bfill()` |
| Missing Data | ffill | Forward fill | `df.ffill()` |

### 11. Data Types & Conversion

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Data Types | astype | Cast to a specific dtype | `df["col"].astype("int32")` |
| Data Types | astype category | Convert to categorical | `df["col"].astype("category")` |
| Data Types | astype string | Convert to string dtype | `df["col"].astype("string")` |
| Data Types | to_numeric | Convert to numeric, coerce errors | `pd.to_numeric(df["col"], errors="coerce")` |
| Data Types | to_numeric downcast | Downcast to smallest numeric type | `pd.to_numeric(df["col"], downcast="integer")` |
| Data Types | to_datetime | Convert to datetime | `pd.to_datetime(df["date_str"])` |
| Data Types | to_datetime format | Parse with explicit format | `pd.to_datetime(df["d"], format="%Y-%m-%d")` |
| Data Types | to_timedelta | Convert to timedelta | `pd.to_timedelta(df["hours"], unit="h")` |
| Data Types | infer_objects | Infer better dtypes for object cols | `df.infer_objects()` |
| Data Types | convert_dtypes | Convert to best nullable dtypes | `df.convert_dtypes()` |
| Data Types | select_dtypes | Select columns by dtype | `df.select_dtypes(include=["number", "datetime"])` |
| Data Types | select_dtypes exclude | Exclude specific dtypes | `df.select_dtypes(exclude=["object"])` |
| Data Types | dtype property | Get dtype of a Series | `df["col"].dtype` |
| Data Types | dtypes property | Get all column dtypes | `df.dtypes` |
| Data Types | object dtype | Generic Python object dtype | `df["col"].dtype == "object"` |
| Data Types | category dtype | Memory-efficient categorical | `df["col"] = df["col"].astype("category")` |
| Data Types | nullable Int64 | Nullable integer dtype | `df["col"].astype("Int64")` |
| Data Types | nullable boolean | Nullable boolean dtype | `df["col"].astype("boolean")` |
| Data Types | nullable string | Nullable string dtype | `df["col"].astype("string")` |
| Data Types | Float64 nullable | Nullable float dtype | `df["col"].astype("Float64")` |

### 12. PyArrow & Modern Backends

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| PyArrow | read_csv pyarrow | Read with PyArrow backend | `df = pd.read_csv("file.csv", dtype_backend="pyarrow")` |
| PyArrow | read_csv engine | Use PyArrow CSV parser | `df = pd.read_csv("file.csv", engine="pyarrow")` |
| PyArrow | string pyarrow | PyArrow-backed string column | `df["col"].astype("string[pyarrow]")` |
| PyArrow | int64 pyarrow | PyArrow-backed integer | `df["col"].astype("int64[pyarrow]")` |
| PyArrow | float64 pyarrow | PyArrow-backed float | `df["col"].astype("float64[pyarrow]")` |
| PyArrow | ArrowDtype | Explicit PyArrow type | `pd.ArrowDtype(pa.string())` |
| PyArrow | convert_dtypes pyarrow | Convert to best PyArrow dtypes | `df.convert_dtypes(dtype_backend="pyarrow")` |
| PyArrow | memory deep | Deep memory usage with PyArrow | `df.memory_usage(deep=True)` |
| PyArrow | pyarrow string default | Proposed default in pandas 3.0 | `pd.options.future.infer_string = True` |
| PyArrow | copy on write | Avoid silent copies (pandas 2.0+) | `pd.options.mode.copy_on_write = True` |

### 13. String Accessor (`.str`)

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| String | str.lower | Lowercase strings | `df["name"].str.lower()` |
| String | str.upper | Uppercase strings | `df["name"].str.upper()` |
| String | str.title | Title case | `df["name"].str.title()` |
| String | str.strip | Remove whitespace | `df["name"].str.strip()` |
| String | str.lstrip | Remove left whitespace | `df["name"].str.lstrip()` |
| String | str.rstrip | Remove right whitespace | `df["name"].str.rstrip()` |
| String | str.len | String length | `df["name"].str.len()` |
| String | str.contains | Substring/regex containment | `df["name"].str.contains("John", regex=False)` |
| String | str.startswith | Starts with prefix | `df["name"].str.startswith("J")` |
| String | str.endswith | Ends with suffix | `df["name"].str.endswith("son")` |
| String | str.match | Regex match at start | `df["name"].str.match(r"^A.*")` |
| String | str.findall | Find all regex matches | `df["name"].str.findall(r"[A-Z]+")` |
| String | str.extract | Extract capture groups | `df["name"].str.extract(r"(\w+) (\w+)")` |
| String | str.extractall | Extract all matches | `df["name"].str.extractall(r"(\w+)")` |
| String | str.split | Split by delimiter | `df["name"].str.split(" ")` |
| String | str.rsplit | Split from right | `df["name"].str.rsplit(" ", n=1)` |
| String | str.partition | Split into 3 parts | `df["name"].str.partition(" ")` |
| String | str.cat | Concatenate strings | `df["a"].str.cat(df["b"], sep="-")` |
| String | str.join | Join list elements with separator | `df["tags"].str.join(", ")` |
| String | str.replace | Replace substring/regex | `df["name"].str.replace("old", "new")` |
| String | str.repeat | Repeat string N times | `df["name"].str.repeat(2)` |
| String | str.zfill | Pad with zeros | `df["code"].str.zfill(5)` |
| String | str.pad | Pad to fixed width | `df["code"].str.pad(5, side="left", fillchar="0")` |
| String | str.center | Center string | `df["name"].str.center(20)` |
| String | str.slice | Slice substring | `df["name"].str.slice(0, 3)` |
| String | str.get | Get character at position | `df["name"].str.get(0)` |
| String | str.count | Count occurrences | `df["name"].str.count("a")` |
| String | str.isnumeric | Check if numeric | `df["val"].str.isnumeric()` |
| String | str.isalpha | Check if alphabetic | `df["val"].str.isalpha()` |
| String | str.isdigit | Check if digits | `df["val"].str.isdigit()` |
| String | str.isspace | Check if whitespace | `df["val"].str.isspace()` |
| String | str.islower | Check if lowercase | `df["val"].str.islower()` |
| String | str.isupper | Check if uppercase | `df["val"].str.isupper()` |
| String | str.istitle | Check if title case | `df["val"].str.istitle()` |
| String | str.wrap | Wrap long strings | `df["text"].str.wrap(80)` |
| String | str.normalize | Unicode normalization | `df["text"].str.normalize("NFC")` |
| String | str.decode | Decode bytes | `df["b"].str.decode("utf-8")` |
| String | str.encode | Encode to bytes | `df["text"].str.encode("utf-8")` |
| String | str.translate | Character translation | `df["text"].str.translate(str.maketrans("a", "b"))` |

### 14. Datetime Accessor (`.dt`)

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Datetime | dt.year | Extract year | `df["date"].dt.year` |
| Datetime | dt.month | Extract month | `df["date"].dt.month` |
| Datetime | dt.day | Extract day of month | `df["date"].dt.day` |
| Datetime | dt.hour | Extract hour | `df["date"].dt.hour` |
| Datetime | dt.minute | Extract minute | `df["date"].dt.minute` |
| Datetime | dt.second | Extract second | `df["date"].dt.second` |
| Datetime | dt.microsecond | Extract microsecond | `df["date"].dt.microsecond` |
| Datetime | dt.nanosecond | Extract nanosecond | `df["date"].dt.nanosecond` |
| Datetime | dt.date | Extract date component | `df["date"].dt.date` |
| Datetime | dt.time | Extract time component | `df["date"].dt.time` |
| Datetime | dt.weekday | Day of week (0=Mon) | `df["date"].dt.weekday` |
| Datetime | dt.dayofweek | Alias for weekday | `df["date"].dt.dayofweek` |
| Datetime | dt.dayofyear | Day of year (1-366) | `df["date"].dt.dayofyear` |
| Datetime | dt.weekofyear | Week of year | `df["date"].dt.isocalendar().week` |
| Datetime | dt.isocalendar | ISO year/week/day | `df["date"].dt.isocalendar()` |
| Datetime | dt.quarter | Quarter of year | `df["date"].dt.quarter` |
| Datetime | dt.is_month_start | First day of month? | `df["date"].dt.is_month_start` |
| Datetime | dt.is_month_end | Last day of month? | `df["date"].dt.is_month_end` |
| Datetime | dt.is_quarter_start | First day of quarter? | `df["date"].dt.is_quarter_start` |
| Datetime | dt.is_quarter_end | Last day of quarter? | `df["date"].dt.is_quarter_end` |
| Datetime | dt.is_year_start | First day of year? | `df["date"].dt.is_year_start` |
| Datetime | dt.is_year_end | Last day of year? | `df["date"].dt.is_year_end` |
| Datetime | dt.is_leap_year | Leap year? | `df["date"].dt.is_leap_year` |
| Datetime | dt.daysinmonth | Days in month | `df["date"].dt.daysinmonth` |
| Datetime | dt.days_in_month | Alias | `df["date"].dt.days_in_month` |
| Datetime | dt.to_period | Convert to Period | `df["date"].dt.to_period("M")` |
| Datetime | dt.to_pydatetime | Convert to Python datetime | `df["date"].dt.to_pydatetime()` |
| Datetime | dt.tz_localize | Add timezone info | `df["date"].dt.tz_localize("UTC")` |
| Datetime | dt.tz_convert | Convert timezone | `df["date"].dt.tz_convert("US/Eastern")` |
| Datetime | dt.floor | Floor to frequency | `df["date"].dt.floor("H")` |
| Datetime | dt.ceil | Ceil to frequency | `df["date"].dt.ceil("H")` |
| Datetime | dt.round | Round to frequency | `df["date"].dt.round("H")` |
| Datetime | dt.strftime | Format as string | `df["date"].dt.strftime("%Y-%m-%d")` |
| Datetime | dt.normalize | Set time to midnight | `df["date"].dt.normalize()` |
| Datetime | dt.total_seconds | Total seconds (for timedelta) | `df["delta"].dt.total_seconds()` |
| Datetime | dt.components | Break down timedelta | `df["delta"].dt.components` |

### 15. Apply, Map & Pipe

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Apply | apply on Series | Apply function to each element | `df["col"].apply(lambda x: x**2)` |
| Apply | apply on DataFrame axis 1 | Apply function row-wise | `df.apply(lambda row: row["a"] + row["b"], axis=1)` |
| Apply | apply on DataFrame axis 0 | Apply function column-wise | `df.apply(lambda col: col.max() - col.min(), axis=0)` |
| Apply | apply with result_type | Control output shape | `df.apply(lambda x: [x.min(), x.max()], axis=1, result_type="expand")` |
| Apply | map on Series | Element-wise mapping with dict/func | `df["col"].map({"a": 1, "b": 2})` |
| Apply | map on Index | Map index labels | `df.index.map(str.upper)` |
| Apply | applymap | Element-wise on entire DataFrame | `df.applymap(lambda x: x**2)` |
| Apply | pipe | Chain operations functionally | `df.pipe(func, arg1, arg2)` |
| Apply | agg / aggregate | Apply multiple reductions | `df.agg(["sum", "mean", "std"])` |
| Apply | agg dict | Per-column aggregations | `df.agg({"A": "sum", "B": "mean"})` |
| Apply | transform | Return same-shape result | `df.transform(lambda x: x - x.mean())` |
| Apply | transform list | Multiple transforms | `df.transform(["sqrt", "exp"])` |
| Apply | np.vectorize | Vectorize a Python function | `np.vectorize(my_func)(df["col"])` |

### 16. GroupBy

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| GroupBy | groupby single | Group by one column | `df.groupby("dept")` |
| GroupBy | groupby multi | Group by multiple columns | `df.groupby(["dept", "role"])` |
| GroupBy | groupby index level | Group by MultiIndex level | `df.groupby(level=0)` |
| GroupBy | groupby with as_index | Keep group key as column | `df.groupby("dept", as_index=False).mean()` |
| GroupBy | groupby sort | Control group sorting | `df.groupby("dept", sort=False).sum()` |
| GroupBy | groupby dropna | Include NA in groups | `df.groupby("dept", dropna=False).sum()` |
| GroupBy | agg single | Single aggregation | `df.groupby("dept")["salary"].agg("mean")` |
| GroupBy | agg multiple | Multiple aggregations | `df.groupby("dept")["salary"].agg(["mean", "max", "min"])` |
| GroupBy | agg dict | Per-column different aggs | `df.groupby("dept").agg({"salary": "mean", "age": "max"})` |
| GroupBy | agg named | Named aggregation | `df.groupby("dept").agg(avg_sal=("salary", "mean"))` |
| GroupBy | transform | Transform within groups | `df.groupby("dept")["salary"].transform("mean")` |
| GroupBy | transform lambda | Custom transform | `df.groupby("dept")["salary"].transform(lambda x: x - x.mean())` |
| GroupBy | filter | Filter groups by condition | `df.groupby("dept").filter(lambda x: x["salary"].mean() > 50000)` |
| GroupBy | first / last | First/last row per group | `df.groupby("dept").first()` |
| GroupBy | nth | Nth row per group | `df.groupby("dept").nth(0)` |
| GroupBy | head | First N rows per group | `df.groupby("dept").head(2)` |
| GroupBy | tail | Last N rows per group | `df.groupby("dept").tail(2)` |
| GroupBy | size | Count rows per group | `df.groupby("dept").size()` |
| GroupBy | count | Non-NA count per group | `df.groupby("dept").count()` |
| GroupBy | nunique | Unique values per group | `df.groupby("dept")["role"].nunique()` |
| GroupBy | sum / mean / std | Built-in group reductions | `df.groupby("dept")["salary"].sum()` |
| GroupBy | min / max | Min/max per group | `df.groupby("dept")["salary"].min()` |
| GroupBy | median | Median per group | `df.groupby("dept")["salary"].median()` |
| GroupBy | quantile | Quantile per group | `df.groupby("dept")["salary"].quantile(0.75)` |
| GroupBy | cumsum | Cumulative sum within group | `df.groupby("dept")["sales"].cumsum()` |
| GroupBy | cumcount | Cumulative count within group | `df.groupby("dept").cumcount()` |
| GroupBy | cummax / cummin | Cumulative max/min | `df.groupby("dept")["sales"].cummax()` |
| GroupBy | rank | Rank within group | `df.groupby("dept")["salary"].rank()` |
| GroupBy | shift | Shift within group | `df.groupby("dept")["sales"].shift(1)` |
| GroupBy | diff | Difference within group | `df.groupby("dept")["sales"].diff()` |
| GroupBy | pct_change | Percent change within group | `df.groupby("dept")["sales"].pct_change()` |
| GroupBy | expanding | Expanding window per group | `df.groupby("dept")["sales"].expanding().sum()` |
| GroupBy | rolling | Rolling window per group | `df.groupby("dept")["sales"].rolling(3).mean()` |
| GroupBy | resample | Time resampling per group | `df.groupby("dept").resample("M")["sales"].sum()` |
| GroupBy | describe | Descriptive stats per group | `df.groupby("dept").describe()` |
| GroupBy | groups | Dict of group labels to indices | `df.groupby("dept").groups` |
| GroupBy | get_group | Extract one group | `df.groupby("dept").get_group("IT")` |
| GroupBy | pipe | Chain groupby operations | `df.groupby("dept").pipe(lambda x: x.mean())` |

### 17. Aggregation & Statistics

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Aggregation | sum | Sum of values | `df["col"].sum()` |
| Aggregation | mean | Arithmetic mean | `df["col"].mean()` |
| Aggregation | median | Median value | `df["col"].median()` |
| Aggregation | std | Standard deviation | `df["col"].std()` |
| Aggregation | var | Variance | `df["col"].var()` |
| Aggregation | min | Minimum value | `df["col"].min()` |
| Aggregation | max | Maximum value | `df["col"].max()` |
| Aggregation | count | Count non-NA values | `df["col"].count()` |
| Aggregation | nunique | Count unique values | `df["col"].nunique()` |
| Aggregation | unique | Array of unique values | `df["col"].unique()` |
| Aggregation | value_counts | Frequency of each value | `df["col"].value_counts()` |
| Aggregation | value_counts normalize | Proportions | `df["col"].value_counts(normalize=True)` |
| Aggregation | quantile | Quantile value | `df["col"].quantile(0.25)` |
| Aggregation | sem | Standard error of mean | `df["col"].sem()` |
| Aggregation | skew | Skewness | `df["col"].skew()` |
| Aggregation | kurt | Kurtosis | `df["col"].kurt()` |
| Aggregation | mad | Mean absolute deviation | `df["col"].mad()` |
| Aggregation | prod | Product of values | `df["col"].prod()` |
| Aggregation | cumsum | Cumulative sum | `df["col"].cumsum()` |
| Aggregation | cummax | Cumulative max | `df["col"].cummax()` |
| Aggregation | cummin | Cumulative min | `df["col"].cummin()` |
| Aggregation | cumprod | Cumulative product | `df["col"].cumprod()` |
| Aggregation | corr | Pearson correlation matrix | `df.corr()` |
| Aggregation | corr method | Spearman/Kendall correlation | `df.corr(method="spearman")` |
| Aggregation | cov | Covariance matrix | `df.cov()` |
| Aggregation | corrwith | Correlation with another DF/Series | `df.corrwith(other_df)` |
| Aggregation | idxmin | Index of minimum value | `df["col"].idxmin()` |
| Aggregation | idxmax | Index of maximum value | `df["col"].idxmax()` |
| Aggregation | mode | Most frequent value(s) | `df["col"].mode()` |
| Aggregation | abs | Absolute value | `df["col"].abs()` |
| Aggregation | clip | Clip to min/max bounds | `df["col"].clip(lower=0, upper=100)` |
| Aggregation | round | Round to N decimals | `df["col"].round(2)` |
| Aggregation | describe | Summary statistics | `df.describe()` |
| Aggregation | describe percentiles | Custom percentiles | `df.describe(percentiles=[0.05, 0.95])` |

### 18. Merging & Joining

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Merge | merge inner | Inner join on key(s) | `pd.merge(df1, df2, on="id")` |
| Merge | merge left | Left join | `pd.merge(df1, df2, on="id", how="left")` |
| Merge | merge right | Right join | `pd.merge(df1, df2, on="id", how="right")` |
| Merge | merge outer | Full outer join | `pd.merge(df1, df2, on="id", how="outer")` |
| Merge | merge cross | Cartesian product | `pd.merge(df1, df2, how="cross")` |
| Merge | merge on multiple | Join on multiple columns | `pd.merge(df1, df2, on=["a", "b"])` |
| Merge | merge left_on right_on | Different column names | `pd.merge(df1, df2, left_on="a", right_on="b")` |
| Merge | merge left_index | Join on index | `pd.merge(df1, df2, left_index=True, right_index=True)` |
| Merge | merge suffixes | Handle overlapping column names | `pd.merge(df1, df2, on="id", suffixes=("_l", "_r"))` |
| Merge | merge indicator | Add merge source column | `pd.merge(df1, df2, on="id", indicator=True)` |
| Merge | merge validate | Validate merge type | `pd.merge(df1, df2, on="id", validate="one_to_many")` |
| Merge | join | Join on index | `df1.join(df2, lsuffix="_l", rsuffix="_r")` |
| Merge | join on column | Join on a specific column | `df1.join(df2.set_index("id"), on="id")` |
| Merge | concat axis 0 | Stack DataFrames vertically | `pd.concat([df1, df2], axis=0)` |
| Merge | concat axis 1 | Concatenate horizontally | `pd.concat([df1, df2], axis=1)` |
| Merge | concat ignore_index | Reset index after concat | `pd.concat([df1, df2], ignore_index=True)` |
| Merge | concat keys | Add hierarchical index | `pd.concat([df1, df2], keys=["a", "b"])` |
| Merge | concat join | Control overlapping columns | `pd.concat([df1, df2], join="inner")` |
| Merge | append | Append rows (deprecated, use concat) | `df1._append(df2)` |
| Merge | combine_first | Fill NA with another DataFrame | `df1.combine_first(df2)` |
| Merge | update | In-place update from another DF | `df1.update(df2)` |
| Merge | merge_ordered | Merge with ordered keys | `pd.merge_ordered(df1, df2, on="id")` |
| Merge | merge_asof | As-of merge for nearest keys | `pd.merge_asof(df1, df2, on="time")` |

### 19. Reshaping & Pivoting

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Reshape | pivot | Reshape long to wide | `df.pivot(index="date", columns="city", values="temp")` |
| Reshape | pivot_table | Aggregated pivot | `df.pivot_table(values="sales", index="month", columns="region", aggfunc="sum")` |
| Reshape | pivot_table margins | Add grand totals | `df.pivot_table(..., margins=True)` |
| Reshape | pivot_table multi | Multiple index/columns | `df.pivot_table(values="sales", index=["year", "month"], columns="region")` |
| Reshape | melt | Unpivot wide to long | `df.melt(id_vars=["id"], value_vars=["A", "B"])` |
| Reshape | melt var_name | Custom variable column name | `df.melt(..., var_name="metric", value_name="score")` |
| Reshape | stack | Pivot columns to MultiIndex rows | `df.stack()` |
| Reshape | unstack | Pivot MultiIndex rows to columns | `df.unstack()` |
| Reshape | unstack level | Unstack specific level | `df.unstack(level="city")` |
| Reshape | explode | Expand list-like elements to rows | `df.explode("tags")` |
| Reshape | explode multi | Explode multiple columns | `df.explode(["tags", "scores"])` |
| Reshape | crosstab | Frequency table | `pd.crosstab(df["A"], df["B"])` |
| Reshape | crosstab normalize | Proportions | `pd.crosstab(df["A"], df["B"], normalize="index")` |
| Reshape | crosstab margins | Add totals | `pd.crosstab(df["A"], df["B"], margins=True)` |
| Reshape | crosstab aggfunc | Aggregated crosstab | `pd.crosstab(df["A"], df["B"], values=df["C"], aggfunc="mean")` |
| Reshape | wide_to_long | Wide to long with stubnames | `pd.wide_to_long(df, stubnames="score", i="id", j="round", sep="_")` |
| Reshape | get_dummies | One-hot encoding | `pd.get_dummies(df, columns=["category"])` |
| Reshape | get_dummies drop_first | Avoid dummy trap | `pd.get_dummies(df, columns=["cat"], drop_first=True)` |
| Reshape | from_dict orient | Create from dict with orientation | `pd.DataFrame.from_dict(d, orient="index")` |
| Reshape | to_dict orient | Convert to dict format | `df.to_dict(orient="records")` |
| Reshape | factorize | Encode to integer codes | `codes, uniques = pd.factorize(df["col"])` |

### 20. Window Functions

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Window | rolling mean | Moving average | `df["col"].rolling(window=3).mean()` |
| Window | rolling sum | Moving sum | `df["col"].rolling(window=3).sum()` |
| Window | rolling std | Moving std dev | `df["col"].rolling(window=3).std()` |
| Window | rolling min / max | Moving min/max | `df["col"].rolling(window=3).min()` |
| Window | rolling count | Moving count | `df["col"].rolling(window=3).count()` |
| Window | rolling median | Moving median | `df["col"].rolling(window=3).median()` |
| Window | rolling apply | Custom rolling function | `df["col"].rolling(3).apply(np.sum)` |
| Window | rolling center | Centered window | `df["col"].rolling(3, center=True).mean()` |
| Window | rolling min_periods | Min non-NA required | `df["col"].rolling(3, min_periods=1).mean()` |
| Window | expanding sum | Expanding cumulative sum | `df["col"].expanding().sum()` |
| Window | expanding mean | Expanding cumulative mean | `df["col"].expanding().mean()` |
| Window | expanding std | Expanding std dev | `df["col"].expanding().std()` |
| Window | ewm mean | Exponentially weighted mean | `df["col"].ewm(span=3).mean()` |
| Window | ewm std | Exponentially weighted std | `df["col"].ewm(span=3).std()` |
| Window | ewm alpha | Specify smoothing factor | `df["col"].ewm(alpha=0.3).mean()` |
| Window | groupby rolling | Rolling within groups | `df.groupby("dept")["sales"].rolling(3).mean()` |
| Window | groupby expanding | Expanding within groups | `df.groupby("dept")["sales"].expanding().sum()` |
| Window | groupby ewm | EWM within groups | `df.groupby("dept")["sales"].ewm(span=3).mean()` |

### 21. Duplicates

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Duplicates | duplicated | Boolean mask of duplicate rows | `df.duplicated()` |
| Duplicates | duplicated subset | Check duplicates by subset | `df.duplicated(subset=["name", "email"])` |
| Duplicates | duplicated keep | Control which duplicate to mark | `df.duplicated(keep="last")` |
| Duplicates | drop_duplicates | Remove duplicate rows | `df.drop_duplicates()` |
| Duplicates | drop_duplicates subset | Remove by subset | `df.drop_duplicates(subset=["name"])` |
| Duplicates | drop_duplicates keep | Keep first/last/none | `df.drop_duplicates(keep="last")` |
| Duplicates | drop_duplicates inplace | Remove in place | `df.drop_duplicates(inplace=True)` |

### 22. Binning & Discretization

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Binning | cut | Equal-width bins | `pd.cut(df["age"], bins=[0, 18, 35, 50, 100], labels=["child", "young", "mid", "senior"])` |
| Binning | cut bins count | Auto-generate N equal-width bins | `pd.cut(df["age"], bins=4)` |
| Binning | qcut | Equal-frequency (quantile) bins | `pd.qcut(df["age"], q=4, labels=["Q1", "Q2", "Q3", "Q4"])` |
| Binning | qcut labels | Custom quantile labels | `pd.qcut(df["score"], q=[0, 0.25, 0.75, 1.0])` |

### 23. Sampling & Random Selection

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Sampling | sample rows | Random sample of rows | `df.sample(n=5)` |
| Sampling | sample frac | Sample by fraction | `df.sample(frac=0.1)` |
| Sampling | sample replace | Sample with replacement | `df.sample(n=5, replace=True)` |
| Sampling | sample weights | Weighted random sample | `df.sample(n=5, weights="priority")` |
| Sampling | sample random_state | Reproducible sample | `df.sample(n=5, random_state=42)` |
| Sampling | sample axis | Sample columns | `df.sample(n=2, axis=1)` |
| Sampling | train test split | Manual split with sample | `train = df.sample(frac=0.8); test = df.drop(train.index)` |

### 24. MultiIndex / Hierarchical Indexing

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| MultiIndex | MultiIndex from_arrays | Create from arrays | `pd.MultiIndex.from_arrays([["A","A","B"], [1,2,1]], names=["letter","num"])` |
| MultiIndex | MultiIndex from_tuples | Create from tuples | `pd.MultiIndex.from_tuples([("A",1),("A",2)], names=["l","n"])` |
| MultiIndex | MultiIndex from_product | Cartesian product index | `pd.MultiIndex.from_product([["A","B"], [1,2]])` |
| MultiIndex | set_index multi | Create MultiIndex from columns | `df.set_index(["dept", "role"])` |
| MultiIndex | index slice | Slice MultiIndex with slice | `df.loc[("IT", slice(None)), :]` |
| MultiIndex | xs cross section | Select at a specific level | `df.xs("IT", level="dept")` |
| MultiIndex | xs drop_level | Keep level in result | `df.xs("IT", level="dept", drop_level=False)` |
| MultiIndex | swaplevel | Swap index levels | `df.swaplevel(0, 1)` |
| MultiIndex | reorder_levels | Reorder index levels | `df.reorder_levels(["role", "dept"])` |
| MultiIndex | sort_index multi | Sort MultiIndex | `df.sort_index()` |
| MultiIndex | reset_index level | Drop one level to column | `df.reset_index(level="dept")` |
| MultiIndex | droplevel | Remove an index level | `df.droplevel("role")` |
| MultiIndex | level values | Get unique values at a level | `df.index.get_level_values("dept")` |
| MultiIndex | groupby level | Group by index level | `df.groupby(level="dept").sum()` |
| MultiIndex | unstack level | Pivot level to columns | `df.unstack(level="role")` |
| MultiIndex | stack | Pivot columns to index | `df.stack()` |

### 25. Categorical Data

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Categorical | astype category | Convert to categorical | `df["col"].astype("category")` |
| Categorical | Categorical constructor | Explicit category creation | `pd.Categorical(["a","b","a"], categories=["a","b","c"], ordered=True)` |
| Categorical | cat categories | View categories | `df["col"].cat.categories` |
| Categorical | cat rename | Rename categories | `df["col"].cat.rename_categories({"a": "A", "b": "B"})` |
| Categorical | cat reorder | Reorder categories | `df["col"].cat.reorder_categories(["b", "a"], ordered=True)` |
| Categorical | cat add | Add new categories | `df["col"].cat.add_categories(["d"])` |
| Categorical | cat remove | Remove categories | `df["col"].cat.remove_categories(["c"])` |
| Categorical | cat remove_unused | Drop unused categories | `df["col"].cat.remove_unused_categories()` |
| Categorical | cat codes | Integer codes | `df["col"].cat.codes` |
| Categorical | cat ordered | Check if ordered | `df["col"].cat.ordered` |
| Categorical | cat as_ordered | Set as ordered | `df["col"].cat.as_ordered()` |
| Categorical | cat as_unordered | Set as unordered | `df["col"].cat.as_unordered()` |
| Categorical | memory savings | Categorical uses less memory | `df["col"].astype("category").memory_usage(deep=True)` |

### 26. Time Series

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Time Series | resample | Resample time series | `df.resample("M")["sales"].sum()` |
| Time Series | resample mean | Monthly average | `df.resample("M")["temp"].mean()` |
| Time Series | resample agg | Multiple resample aggs | `df.resample("W").agg({"sales": "sum", "orders": "count"})` |
| Time Series | resample interpolate | Interpolate after resample | `df.resample("H").interpolate()` |
| Time Series | asfreq | Change frequency without aggregation | `df.asfreq("D")` |
| Time Series | shift | Lag data by N periods | `df["sales"].shift(1)` |
| Time Series | shift freq | Shift by time frequency | `df["sales"].shift(periods=1, freq="D")` |
| Time Series | tshift | Shift time index | `df.tshift(1, freq="D")` |
| Time Series | diff | First difference | `df["sales"].diff()` |
| Time Series | diff periods | N-th difference | `df["sales"].diff(periods=7)` |
| Time Series | pct_change | Percent change | `df["sales"].pct_change()` |
| Time Series | pct_change periods | N-period percent change | `df["sales"].pct_change(periods=12)` |
| Time Series | rolling | Rolling window | `df["sales"].rolling(7).mean()` |
| Time Series | expanding | Expanding window | `df["sales"].expanding().sum()` |
| Time Series | ewm | Exponentially weighted | `df["sales"].ewm(span=7).mean()` |
| Time Series | to_period | Convert to period | `df.index.to_period("M")` |
| Time Series | to_timestamp | Convert period to timestamp | `df.index.to_timestamp()` |
| Time Series | tz_localize | Add timezone | `df.tz_localize("UTC")` |
| Time Series | tz_convert | Convert timezone | `df.tz_convert("US/Eastern")` |
| Time Series | between_time | Select between times | `df.between_time("09:00", "17:00")` |
| Time Series | at_time | Select at exact time | `df.at_time("12:00")` |
| Time Series | first / last | Select by date offset | `df.first("3M")` |
| Time Series | truncate | Truncate before/after dates | `df.truncate(before="2024-01-15", after="2024-06-01")` |
| Time Series | date_range | Generate datetime index | `pd.date_range("2024-01-01", periods=10, freq="B")` |
| Time Series | bdate_range | Business day range | `pd.bdate_range("2024-01-01", periods=10)` |
| Time Series | period_range | Generate period index | `pd.period_range("2024-01", periods=4, freq="M")` |
| Time Series | timedelta_range | Generate timedelta index | `pd.timedelta_range("1 day", periods=5)` |
| Time Series | infer_freq | Infer frequency from index | `pd.infer_freq(df.index)` |
| Time Series | Grouper | Time-aware groupby key | `df.groupby(pd.Grouper(key="date", freq="M")).sum()` |

### 27. Visualization

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Visualization | plot line | Line plot | `df.plot(kind="line", x="date", y="sales")` |
| Visualization | plot bar | Vertical bar chart | `df.plot(kind="bar", x="category", y="sales")` |
| Visualization | plot barh | Horizontal bar chart | `df.plot(kind="barh", x="category", y="sales")` |
| Visualization | plot hist | Histogram | `df["col"].plot(kind="hist", bins=20)` |
| Visualization | plot box | Box plot | `df.plot(kind="box")` |
| Visualization | plot scatter | Scatter plot | `df.plot(kind="scatter", x="x", y="y")` |
| Visualization | plot area | Area chart | `df.plot(kind="area")` |
| Visualization | plot pie | Pie chart | `df["col"].plot(kind="pie")` |
| Visualization | plot hexbin | Hexbin plot | `df.plot(kind="hexbin", x="x", y="y", gridsize=20)` |
| Visualization | plot density | KDE plot | `df["col"].plot(kind="density")` |
| Visualization | plot subplots | Multiple subplots | `df.plot(subplots=True, figsize=(10, 8))` |
| Visualization | plot secondary_y | Secondary y-axis | `df.plot(secondary_y=["col2"])` |
| Visualization | hist | Histogram shortcut | `df.hist(bins=20, figsize=(10, 8))` |
| Visualization | boxplot | Boxplot shortcut | `df.boxplot(column="sales", by="dept")` |
| Visualization | scatter_matrix | Pairwise scatter | `pd.plotting.scatter_matrix(df)` |
| Visualization | andrews_curves | Andrews curves | `pd.plotting.andrews_curves(df, "class")` |
| Visualization | parallel_coordinates | Parallel coordinates | `pd.plotting.parallel_coordinates(df, "class")` |
| Visualization | lag_plot | Lag plot | `pd.plotting.lag_plot(df["col"])` |
| Visualization | autocorrelation_plot | Autocorrelation | `pd.plotting.autocorrelation_plot(df["col"])` |
| Visualization | table | Add table to plot | `df.plot(table=True)` |
| Visualization | style bar | Color bars in styled output | `df.style.bar(subset=["sales"], color="#d65f5f")` |
| Visualization | style background_gradient | Heatmap-style coloring | `df.style.background_gradient(cmap="coolwarm")` |
| Visualization | style highlight_max | Highlight max values | `df.style.highlight_max(color="green")` |
| Visualization | style highlight_min | Highlight min values | `df.style.highlight_min(color="red")` |
| Visualization | style highlight_null | Highlight missing values | `df.style.highlight_null(color="yellow")` |
| Visualization | style applymap | Custom cell styling | `df.style.applymap(lambda x: "color: red" if x < 0 else "")` |
| Visualization | style apply | Row/column styling | `df.style.apply(highlight_row, axis=1)` |
| Visualization | style format | Format numbers | `df.style.format({"sales": "${:,.2f}"})` |
| Visualization | style hide_index | Hide row index | `df.style.hide()` |
| Visualization | style to_html | Export styled table to HTML | `df.style.to_html("styled.html")` |
| Visualization | style to_latex | Export styled table to LaTeX | `df.style.to_latex()` |

### 28. Options, Settings & Performance

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Performance | eval | Evaluate expression string | `df.eval("C = A + B", inplace=True)` |
| Performance | eval query engine | Use numexpr for speed | `df.eval("C = A + B", engine="numexpr")` |
| Performance | query engine | Query with numexpr | `df.query("A > B", engine="numexpr")` |
| Performance | copy on write | Avoid silent copies (2.0+) | `pd.options.mode.copy_on_write = True` |
| Performance | chained assignment warning | Disable SettingWithCopyWarning | `pd.options.mode.chained_assignment = None` |
| Performance | nullable dtypes | Use nullable Int64, boolean, string | `df.convert_dtypes()` |
| Performance | pyarrow backend | Use PyArrow for I/O and dtypes | `pd.read_csv("file.csv", dtype_backend="pyarrow")` |
| Performance | infer string | Future string inference | `pd.options.future.infer_string = True` |
| Performance | option context | Temporarily change settings | `with pd.option_context("display.max_rows", 10): print(df)` |
| Performance | set option | Change global option | `pd.set_option("display.max_columns", 100)` |
| Performance | get option | Read global option | `pd.get_option("display.max_rows")` |
| Performance | reset option | Reset to default | `pd.reset_option("display.max_columns")` |
| Performance | describe option | Show option docs | `pd.describe_option("display.max_rows")` |
