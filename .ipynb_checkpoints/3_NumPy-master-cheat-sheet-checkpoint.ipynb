# %%
### 1. Import & Setup

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Import & Setup | import numpy | Standard import with alias | `import numpy as np` |
| Import & Setup | check version | Get installed NumPy version | `np.__version__` |
| Import & Setup | show config | Build configuration | `np.show_config()` |
| Import & Setup | set print options | Control array printing | `np.set_printoptions(precision=3, suppress=True)` |
| Import & Setup | get print options | Read print settings | `np.get_printoptions()` |
| Import & Setup | set errstate | Control floating-point errors | `np.seterr(all="warn")` |
| Import & Setup | errstate context | Temporary error handling | `with np.errstate(divide="ignore"): ...` |
| Import & Setup | random seed legacy | Set legacy random seed | `np.random.seed(42)` |
| Import & Setup | default_rng | Modern random Generator | `rng = np.random.default_rng(42)` |
| Import & Setup | array_api namespace | NumPy 2.0 array API | `import numpy.array_api as npx` |

### 2. Array Creation

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Array Creation | array | Create array from list/tuple | `np.array([1, 2, 3])` |
| Array Creation | array dtype | Specify data type | `np.array([1, 2, 3], dtype=np.float32)` |
| Array Creation | array copy | Force copy of data | `np.array(a, copy=True)` |
| Array Creation | array ndmin | Minimum dimensions | `np.array([1, 2, 3], ndmin=2)` |
| Array Creation | zeros | Array of zeros | `np.zeros((3, 4))` |
| Array Creation | zeros dtype | Zeros with custom dtype | `np.zeros(5, dtype=np.int32)` |
| Array Creation | zeros_like | Zeros matching shape of another | `np.zeros_like(a)` |
| Array Creation | ones | Array of ones | `np.ones((2, 3))` |
| Array Creation | ones_like | Ones matching shape | `np.ones_like(a)` |
| Array Creation | empty | Uninitialized array (fast) | `np.empty((3, 3))` |
| Array Creation | empty_like | Empty matching shape | `np.empty_like(a)` |
| Array Creation | full | Array filled with value | `np.full((2, 2), 7)` |
| Array Creation | full_like | Full matching shape | `np.full_like(a, 9)` |
| Array Creation | eye | Identity-like matrix with offset | `np.eye(3, k=1)` |
| Array Creation | identity | Square identity matrix | `np.identity(4)` |
| Array Creation | diag | Diagonal matrix from vector | `np.diag([1, 2, 3])` |
| Array Creation | diag extract | Extract diagonal | `np.diag(a)` |
| Array Creation | arange | Range of values (like Python range) | `np.arange(0, 10, 2)` |
| Array Creation | arange float | Range with float step | `np.arange(0, 1, 0.1)` |
| Array Creation | linspace | Evenly spaced numbers | `np.linspace(0, 1, 5)` |
| Array Creation | linspace endpoint | Exclude endpoint | `np.linspace(0, 1, 5, endpoint=False)` |
| Array Creation | logspace | Logarithmically spaced | `np.logspace(0, 2, 5)` |
| Array Creation | geomspace | Geometrically spaced | `np.geomspace(1, 100, 5)` |
| Array Creation | meshgrid | Coordinate matrices from vectors | `X, Y = np.meshgrid(x, y)` |
| Array Creation | mgrid | Dense mesh-grid (indexing) | `np.mgrid[0:3, 0:3]` |
| Array Creation | ogrid | Open mesh-grid (sparse) | `np.ogrid[0:3, 0:3]` |
| Array Creation | fromfunction | Array from function on indices | `np.fromfunction(lambda i,j: i+j, (3,3))` |
| Array Creation | fromiter | Array from iterable | `np.fromiter(range(5), dtype=int)` |
| Array Creation | fromstring | Array from string | `np.fromstring("1 2 3", sep=" ")` |
| Array Creation | frombuffer | Array from buffer/memoryview | `np.frombuffer(b"\\x01\\x02", dtype=np.uint8)` |
| Array Creation | copy | Copy array (NumPy 2.0 behavior) | `np.copy(a)` or `a.copy()` |
| Array Creation | asarray | Convert to array without copy if possible | `np.asarray([1, 2, 3])` |
| Array Creation | asanyarray | Convert, pass subclasses through | `np.asanyarray(a)` |
| Array Creation | ascontiguousarray | Force C-contiguous | `np.ascontiguousarray(a)` |
| Array Creation | asfortranarray | Force Fortran-contiguous | `np.asfortranarray(a)` |
| Array Creation | require | Ensure specific requirements | `np.require(a, requirements=["C", "O"])` |
| Array Creation | loadtxt | Load from text file | `np.loadtxt("data.txt", delimiter=",")` |
| Array Creation | genfromtxt | Load with missing data handling | `np.genfromtxt("data.txt", delimiter=",", filling_values=0)` |
| Array Creation | fromregex | Load using regex | `np.fromregex("file.txt", r"(\\d+)", [("num", int)])` |
| Array Creation | load | Load .npy file | `np.load("array.npy")` |
| Array Creation | memmap | Memory-mapped array | `np.memmap("data.bin", dtype="float32", mode="r", shape=(100,100))` |

### 3. Data Types (dtypes)

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Data Types | int8 / int16 / int32 / int64 | Signed integers | `np.array([1,2,3], dtype=np.int32)` |
| Data Types | uint8 / uint16 / uint32 / uint64 | Unsigned integers | `np.array([1,2,3], dtype=np.uint8)` |
| Data Types | float16 / float32 / float64 / float128 | Floating-point | `np.array([1.0,2.0], dtype=np.float64)` |
| Data Types | complex64 / complex128 / complex256 | Complex numbers | `np.array([1+2j], dtype=np.complex128)` |
| Data Types | bool_ | Boolean | `np.array([True, False], dtype=np.bool_)` |
| Data Types | object_ | Python object | `np.array(["a", 1, None], dtype=object)` |
| Data Types | str_ | Fixed-width Unicode string | `np.array(["hello"], dtype="U10")` |
| Data Types | bytes_ | Fixed-width byte string | `np.array([b"hello"], dtype="S10")` |
| Data Types | StringDType | Variable-length strings (NumPy 2.0+) | `np.array(["hello"], dtype=np.dtypes.StringDType())` |
| Data Types | datetime64 | Date and time | `np.array(["2024-01-01"], dtype="datetime64[D]")` |
| Data Types | timedelta64 | Time differences | `np.array([1, 2, 3], dtype="timedelta64[h]")` |
| Data Types | void | Raw data | `np.array([(1,2)], dtype="V8")` |
| Data Types | dtype object | Create dtype object | `np.dtype("float64")` |
| Data Types | dtype structured | Structured dtype with fields | `np.dtype([("x", float), ("y", float)])` |
| Data Types | dtype itemsize | Bytes per element | `np.dtype("float64").itemsize` |
| Data Types | dtype alignment | Alignment requirement | `np.dtype("float64").alignment` |
| Data Types | can_cast | Check if safe cast possible | `np.can_cast(np.int32, np.float64)` |
| Data Types | promote_types | Find common dtype | `np.promote_types(np.int32, np.float32)` |
| Data Types | result_type | Result dtype from inputs | `np.result_type(3, np.arange(7, dtype="i1"))` |
| Data Types | issubdtype | Check subtype relationship | `np.issubdtype(np.int64, np.integer)` |
| Data Types | find_common_type | Common type for arrays | `np.find_common_type([np.int32, np.float32], [])` |
| Data Types | min_scalar_type | Smallest type holding scalar | `np.min_scalar_type(1.5)` |
| Data Types | obj2sctype | Object to scalar type | `np.obj2sctype(np.int32)` |
| Data Types | typecodes | Character codes for types | `np.typecodes` |

### 4. Array Attributes & Inspection

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Attributes | shape | Tuple of dimensions | `a.shape` |
| Attributes | ndim | Number of dimensions | `a.ndim` |
| Attributes | size | Total number of elements | `a.size` |
| Attributes | itemsize | Bytes per element | `a.itemsize` |
| Attributes | nbytes | Total bytes consumed | `a.nbytes` |
| Attributes | dtype | Data type of elements | `a.dtype` |
| Attributes | T | Transpose | `a.T` |
| Attributes | flat | 1D iterator over array | `a.flat[5]` |
| Attributes | real | Real part of complex array | `a.real` |
| Attributes | imag | Imaginary part | `a.imag` |
| Attributes | data | Memory address of data | `a.data` |
| Attributes | base | Base object if view | `a.base` |
| Attributes | flags | Memory layout flags | `a.flags` |
| Attributes | flags C_CONTIGUOUS | Check C-order | `a.flags["C_CONTIGUOUS"]` |
| Attributes | flags F_CONTIGUOUS | Check Fortran-order | `a.flags["F_CONTIGUOUS"]` |
| Attributes | flags OWNDATA | Owns its data? | `a.flags["OWNDATA"]` |
| Attributes | strides | Bytes to step in each dimension | `a.strides` |
| Attributes | ctypes | C-compatible types | `a.ctypes` |
| Attributes | __array_interface__ | Protocol for array sharing | `a.__array_interface__` |

### 5. Indexing & Slicing

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Indexing | basic index | Element by index | `a[0]` or `a[0, 1]` |
| Indexing | slice | Slice range | `a[1:5]` or `a[1:5:2]` |
| Indexing | negative index | From end | `a[-1]` or `a[-3:]` |
| Indexing | multi-dim slice | Slice in multiple dims | `a[0:2, 1:3]` |
| Indexing | ellipsis | All remaining dimensions | `a[..., 0]` |
| Indexing | newaxis | Add dimension | `a[:, np.newaxis]` |
| Indexing | boolean mask | Filter by condition | `a[a > 0]` |
| Indexing | fancy index | Index with array | `a[[0, 2, 4]]` |
| Indexing | fancy multi-dim | Index rows and cols | `a[[0,1], [2,3]]` |
| Indexing | ix_ | Open mesh from multiple sequences | `a[np.ix_([0,1], [2,3])]` |
| Indexing | where | Indices where condition is True | `np.where(a > 0)` |
| Indexing | where with x,y | Choose x or y based on condition | `np.where(a > 0, a, 0)` |
| Indexing | select | Choose from multiple conditions | `np.select([a<0, a==0, a>0], [-1, 0, 1])` |
| Indexing | choose | Choose values from choices | `np.choose([0,1,0], [a, b])` |
| Indexing | clip | Clip to min/max | `np.clip(a, 0, 1)` |
| Indexing | put | Put values at indices | `np.put(a, [0,2], [99, 88])` |
| Indexing | putmask | Put values where mask is True | `np.putmask(a, a < 0, 0)` |
| Indexing | take | Take elements along axis | `np.take(a, [0, 2, 4], axis=0)` |
| Indexing | take_along_axis | Take using indices array | `np.take_along_axis(a, idx, axis=1)` |
| Indexing | compress | Return selected elements | `np.compress(a > 0, a)` |
| Indexing | extract | Elements satisfying condition | `np.extract(a > 0, a)` |
| Indexing | nonzero | Indices of non-zero elements | `np.nonzero(a)` |
| Indexing | flatnonzero | Flat indices of non-zero | `np.flatnonzero(a)` |
| Indexing | argwhere | Indices where condition True | `np.argwhere(a > 0)` |
| Indexing | unravel_index | Convert flat index to multi-dim | `np.unravel_index(7, (3,3))` |
| Indexing | ravel_multi_index | Convert multi-dim to flat | `np.ravel_multi_index((2,1), (3,3))` |
| Indexing | diag_indices | Indices for diagonal | `np.diag_indices(3)` |
| Indexing | diag_indices_from | Diag indices from array | `np.diag_indices_from(a)` |
| Indexing | tril_indices | Lower triangle indices | `np.tril_indices(3)` |
| Indexing | triu_indices | Upper triangle indices | `np.triu_indices(3)` |
| Indexing | mask_indices | Masked triangle indices | `np.mask_indices(3, np.triu)` |
| Indexing | s_ | Build index tuples | `np.s_[1:5:2, 3:]` |
| Indexing | index_exp | Index expression | `np.index_exp[1:5, 3:]` |

### 6. Broadcasting

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Broadcasting | add scalar | Add scalar to array | `a + 5` |
| Broadcasting | add 1D to 2D | Row-wise broadcast | `a + [1, 2, 3]` |
| Broadcasting | add column vector | Column-wise broadcast | `a + [[1], [2]]` |
| Broadcasting | newaxis | Add axis for broadcast | `a[:, np.newaxis] + b` |
| Broadcasting | expand_dims | Add axis at position | `np.expand_dims(a, axis=1)` |
| Broadcasting | broadcast_to | Broadcast to shape | `np.broadcast_to(a, (3, 3))` |
| Broadcasting | broadcast_arrays | Broadcast multiple arrays | `np.broadcast_arrays(a, b)` |
| Broadcasting | broadcast | Broadcast object | `np.broadcast(a, b)` |
| Broadcasting | shape mismatch | Incompatible shapes error | `a.shape` vs `b.shape` must align |

### 7. Universal Functions (ufuncs)

#### 7a. Arithmetic ufuncs

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Arithmetic | add | Element-wise addition | `np.add(a, b)` |
| Arithmetic | subtract | Element-wise subtraction | `np.subtract(a, b)` |
| Arithmetic | multiply | Element-wise multiplication | `np.multiply(a, b)` |
| Arithmetic | divide | Element-wise division | `np.divide(a, b)` |
| Arithmetic | true_divide | True division (always float) | `np.true_divide(a, b)` |
| Arithmetic | floor_divide | Floor division | `np.floor_divide(a, b)` |
| Arithmetic | negative | Negation | `np.negative(a)` |
| Arithmetic | positive | Unary plus | `np.positive(a)` |
| Arithmetic | power | Element-wise power | `np.power(a, 3)` |
| Arithmetic | float_power | Power using float | `np.float_power(a, 3)` |
| Arithmetic | remainder | Remainder (like %) | `np.remainder(a, b)` |
| Arithmetic | mod | Modulo | `np.mod(a, b)` |
| Arithmetic | fmod | C-style modulo | `np.fmod(a, b)` |
| Arithmetic | divmod | Quotient and remainder | `np.divmod(a, b)` |
| Arithmetic | absolute / abs | Absolute value | `np.abs(a)` |
| Arithmetic | fabs | Absolute (float) | `np.fabs(a)` |
| Arithmetic | rint | Round to nearest integer | `np.rint(a)` |
| Arithmetic | sign | Sign of number | `np.sign(a)` |
| Arithmetic | heaviside | Heaviside step function | `np.heaviside(a, 0.5)` |
| Arithmetic | conj / conjugate | Complex conjugate | `np.conj(a)` |
| Arithmetic | exp | Exponential e^x | `np.exp(a)` |
| Arithmetic | exp2 | 2^x | `np.exp2(a)` |
| Arithmetic | log | Natural logarithm | `np.log(a)` |
| Arithmetic | log2 | Base-2 logarithm | `np.log2(a)` |
| Arithmetic | log10 | Base-10 logarithm | `np.log10(a)` |
| Arithmetic | log1p | log(1+x) accurately | `np.log1p(a)` |
| Arithmetic | expm1 | exp(x)-1 accurately | `np.expm1(a)` |
| Arithmetic | sqrt | Square root | `np.sqrt(a)` |
| Arithmetic | cbrt | Cube root | `np.cbrt(a)` |
| Arithmetic | square | Square | `np.square(a)` |
| Arithmetic | reciprocal | 1/x | `np.reciprocal(a)` |

#### 7b. Trigonometric & Hyperbolic ufuncs

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Trig | sin / cos / tan | Trigonometric functions | `np.sin(a)` |
| Trig | arcsin / arccos / arctan | Inverse trigonometric | `np.arcsin(a)` |
| Trig | arctan2 | Quadrant-aware arctan | `np.arctan2(y, x)` |
| Trig | hypot | Euclidean distance | `np.hypot(3, 4)` |
| Trig | sinh / cosh / tanh | Hyperbolic functions | `np.sinh(a)` |
| Trig | arcsinh / arccosh / arctanh | Inverse hyperbolic | `np.arcsinh(a)` |
| Trig | deg2rad / radians | Degrees to radians | `np.deg2rad(180)` |
| Trig | rad2deg / degrees | Radians to degrees | `np.rad2deg(np.pi)` |

#### 7c. Comparison & Logical ufuncs

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Comparison | greater / > | Element-wise greater | `np.greater(a, b)` |
| Comparison | greater_equal / >= | Greater or equal | `np.greater_equal(a, b)` |
| Comparison | less / < | Less than | `np.less(a, b)` |
| Comparison | less_equal / <= | Less or equal | `np.less_equal(a, b)` |
| Comparison | equal / == | Equal | `np.equal(a, b)` |
| Comparison | not_equal / != | Not equal | `np.not_equal(a, b)` |
| Logical | logical_and | Element-wise AND | `np.logical_and(a, b)` |
| Logical | logical_or | Element-wise OR | `np.logical_or(a, b)` |
| Logical | logical_xor | Element-wise XOR | `np.logical_xor(a, b)` |
| Logical | logical_not | Element-wise NOT | `np.logical_not(a)` |

#### 7d. Bitwise ufuncs

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Bitwise | bitwise_and / & | Bitwise AND | `np.bitwise_and(a, b)` |
| Bitwise | bitwise_or / | | Bitwise OR | `np.bitwise_or(a, b)` |
| Bitwise | bitwise_xor / ^ | Bitwise XOR | `np.bitwise_xor(a, b)` |
| Bitwise | invert / ~ | Bitwise NOT | `np.invert(a)` |
| Bitwise | left_shift / << | Left shift | `np.left_shift(a, 2)` |
| Bitwise | right_shift / >> | Right shift | `np.right_shift(a, 2)` |

#### 7e. Floating-point ufuncs

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Float | isfinite | Finite number? | `np.isfinite(a)` |
| Float | isinf | Infinite? | `np.isinf(a)` |
| Float | isnan | NaN? | `np.isnan(a)` |
| Float | isnat | NaT (datetime)? | `np.isnat(a)` |
| Float | signbit | Negative sign bit? | `np.signbit(a)` |
| Float | copysign | Copy sign from one to another | `np.copysign(a, b)` |
| Float | nextafter | Next representable float | `np.nextafter(1.0, 2.0)` |
| Float | spacing | Distance to next float | `np.spacing(1.0)` |
| Float | modf | Fractional and integral parts | `np.modf(a)` |
| Float | ldexp | a * 2^b | `np.ldexp(a, b)` |
| Float | frexp | Mantissa and exponent | `np.frexp(a)` |
| Float | fmax | Element-wise max (ignores NaN) | `np.fmax(a, b)` |
| Float | fmin | Element-wise min (ignores NaN) | `np.fmin(a, b)` |
| Float | maximum | Element-wise max (propagates NaN) | `np.maximum(a, b)` |
| Float | minimum | Element-wise min (propagates NaN) | `np.minimum(a, b)` |
| Float | ceil | Ceiling | `np.ceil(a)` |
| Float | floor | Floor | `np.floor(a)` |
| Float | trunc | Truncate toward zero | `np.trunc(a)` |
| Float | around / round | Round to N decimals | `np.around(a, 2)` |
| Float | fix | Round toward zero | `np.fix(a)` |

### 8. Aggregation & Statistics

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Aggregation | sum | Sum of all elements | `np.sum(a)` or `a.sum()` |
| Aggregation | sum axis | Sum along axis | `np.sum(a, axis=0)` |
| Aggregation | prod | Product of all elements | `np.prod(a)` |
| Aggregation | prod axis | Product along axis | `np.prod(a, axis=1)` |
| Aggregation | mean | Arithmetic mean | `np.mean(a)` |
| Aggregation | mean axis | Mean along axis | `np.mean(a, axis=0)` |
| Aggregation | std | Standard deviation | `np.std(a)` |
| Aggregation | std ddof | Sample std (ddof=1) | `np.std(a, ddof=1)` |
| Aggregation | var | Variance | `np.var(a)` |
| Aggregation | var ddof | Sample variance | `np.var(a, ddof=1)` |
| Aggregation | min | Minimum value | `np.min(a)` |
| Aggregation | max | Maximum value | `np.max(a)` |
| Aggregation | argmin | Index of minimum | `np.argmin(a)` |
| Aggregation | argmax | Index of maximum | `np.argmax(a)` |
| Aggregation | argmin axis | Index of min along axis | `np.argmin(a, axis=0)` |
| Aggregation | argmax axis | Index of max along axis | `np.argmax(a, axis=0)` |
| Aggregation | median | Median | `np.median(a)` |
| Aggregation | median axis | Median along axis | `np.median(a, axis=0)` |
| Aggregation | percentile | Percentile value | `np.percentile(a, 75)` |
| Aggregation | percentile axis | Percentile along axis | `np.percentile(a, 75, axis=0)` |
| Aggregation | quantile | Quantile (0-1) | `np.quantile(a, 0.75)` |
| Aggregation | average | Weighted average | `np.average(a, weights=w)` |
| Aggregation | nanmean | Mean ignoring NaN | `np.nanmean(a)` |
| Aggregation | nansum | Sum ignoring NaN | `np.nansum(a)` |
| Aggregation | nanstd | Std ignoring NaN | `np.nanstd(a)` |
| Aggregation | nanvar | Variance ignoring NaN | `np.nanvar(a)` |
| Aggregation | nanmin | Min ignoring NaN | `np.nanmin(a)` |
| Aggregation | nanmax | Max ignoring NaN | `np.nanmax(a)` |
| Aggregation | nanargmin | Argmin ignoring NaN | `np.nanargmin(a)` |
| Aggregation | nanargmax | Argmax ignoring NaN | `np.nanargmax(a)` |
| Aggregation | nanmedian | Median ignoring NaN | `np.nanmedian(a)` |
| Aggregation | nanpercentile | Percentile ignoring NaN | `np.nanpercentile(a, 75)` |
| Aggregation | nanquantile | Quantile ignoring NaN | `np.nanquantile(a, 0.75)` |
| Aggregation | count_nonzero | Count non-zero elements | `np.count_nonzero(a)` |
| Aggregation | count_nonzero axis | Count along axis | `np.count_nonzero(a, axis=1)` |

### 9. Cumulative & Differential Operations

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Cumulative | cumsum | Cumulative sum | `np.cumsum(a)` |
| Cumulative | cumsum axis | Cumsum along axis | `np.cumsum(a, axis=0)` |
| Cumulative | cumprod | Cumulative product | `np.cumprod(a)` |
| Cumulative | nancumsum | Cumsum ignoring NaN | `np.nancumsum(a)` |
| Cumulative | nancumprod | Cumprod ignoring NaN | `np.nancumprod(a)` |
| Cumulative | cumulative_sum | Cumulative sum (NumPy 2.0) | `np.cumulative_sum(a)` |
| Cumulative | cumulative_prod | Cumulative product (NumPy 2.0) | `np.cumulative_prod(a)` |
| Differential | diff | N-th discrete difference | `np.diff(a, n=2)` |
| Differential | diff axis | Diff along axis | `np.diff(a, axis=0)` |
| Differential | ediff1d | Differences between flattened elements | `np.ediff1d(a)` |
| Differential | gradient | N-dimensional gradient | `np.gradient(a)` |
| Differential | trapz / trapezoid | Trapezoidal integration | `np.trapezoid(a, x)` |
| Vector | cross | Cross product | `np.cross(a, b)` |
| Vector | dot | Dot product | `np.dot(a, b)` |
| Vector | inner | Inner product | `np.inner(a, b)` |
| Vector | outer | Outer product | `np.outer(a, b)` |
| Vector | kron | Kronecker product | `np.kron(a, b)` |
| Vector | tensordot | Tensor contraction | `np.tensordot(a, b, axes=1)` |
| Vector | einsum | Einstein summation | `np.einsum("ij,jk->ik", a, b)` |
| Vector | vdot | Complex dot product | `np.vdot(a, b)` |
| Vector | matmul / @ | Matrix multiplication | `a @ b` or `np.matmul(a, b)` |
| Vector | vecdot | Vector dot along axis (NumPy 2.0) | `np.vecdot(a, b, axis=0)` |

### 10. Sorting & Searching

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Sorting | sort | In-place sort | `a.sort()` |
| Sorting | sort axis | Sort along axis | `np.sort(a, axis=0)` |
| Sorting | sort kind | Sort algorithm (quicksort/mergesort/heapsort/stable) | `np.sort(a, kind="mergesort")` |
| Sorting | argsort | Indices that would sort array | `np.argsort(a)` |
| Sorting | argsort axis | Argsort along axis | `np.argsort(a, axis=1)` |
| Sorting | lexsort | Sort by multiple keys | `np.lexsort((b, a))` |
| Sorting | partition | Partial sort (k smallest) | `np.partition(a, 3)` |
| Sorting | argpartition | Indices for partition | `np.argpartition(a, 3)` |
| Sorting | searchsorted | Find insertion indices | `np.searchsorted(a, 2.5)` |
| Sorting | searchsorted side | Left or right insertion | `np.searchsorted(a, 2, side="right")` |
| Sorting | argwhere | Indices of True elements | `np.argwhere(a > 0)` |
| Sorting | nonzero | Indices of non-zero | `np.nonzero(a)` |
| Sorting | flatnonzero | Flat indices of non-zero | `np.flatnonzero(a)` |
| Sorting | count_nonzero | Count non-zero elements | `np.count_nonzero(a)` |
| Sorting | extract | Extract elements by condition | `np.extract(a > 0, a)` |
| Sorting | unique | Unique elements | `np.unique(a)` |
| Sorting | unique return_counts | Unique with counts | `np.unique(a, return_counts=True)` |
| Sorting | unique return_index | Unique with first indices | `np.unique(a, return_index=True)` |
| Sorting | unique return_inverse | Unique with reconstruction indices | `np.unique(a, return_inverse=True)` |
| Set Ops | intersect1d | Sorted intersection | `np.intersect1d(a, b)` |
| Set Ops | union1d | Sorted union | `np.union1d(a, b)` |
| Set Ops | setdiff1d | Set difference | `np.setdiff1d(a, b)` |
| Set Ops | setxor1d | Symmetric difference | `np.setxor1d(a, b)` |
| Set Ops | in1d | Test membership (flattened) | `np.in1d(a, b)` |
| Set Ops | isin | Test membership (preserves shape) | `np.isin(a, b)` |

### 11. Shape Manipulation

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Shape | reshape | Change shape (shares data if possible) | `a.reshape((2, 3))` |
| Shape | reshape -1 | Infer dimension | `a.reshape((2, -1))` |
| Shape | ravel | Flatten to 1D (view if possible) | `a.ravel()` |
| Shape | flatten | Flatten to 1D (always copy) | `a.flatten()` |
| Shape | transpose / T | Transpose dimensions | `a.T` or `np.transpose(a)` |
| Shape | transpose axes | Custom axis order | `np.transpose(a, (1, 0, 2))` |
| Shape | swapaxes | Swap two axes | `np.swapaxes(a, 0, 1)` |
| Shape | moveaxis | Move axis to new position | `np.moveaxis(a, 0, -1)` |
| Shape | rollaxis | Roll axis to new position | `np.rollaxis(a, 2)` |
| Shape | squeeze | Remove length-1 dimensions | `np.squeeze(a)` |
| Shape | squeeze axis | Squeeze specific axis | `np.squeeze(a, axis=1)` |
| Shape | expand_dims | Add axis at position | `np.expand_dims(a, axis=1)` |
| Shape | atleast_1d | Ensure at least 1D | `np.atleast_1d(a)` |
| Shape | atleast_2d | Ensure at least 2D | `np.atleast_2d(a)` |
| Shape | atleast_3d | Ensure at least 3D | `np.atleast_3d(a)` |
| Shape | stack | Stack arrays along new axis | `np.stack([a, b], axis=0)` |
| Shape | vstack | Stack vertically (row-wise) | `np.vstack((a, b))` |
| Shape | hstack | Stack horizontally (col-wise) | `np.hstack((a, b))` |
| Shape | dstack | Stack depth-wise (3rd axis) | `np.dstack((a, b))` |
| Shape | column_stack | Stack 1D arrays as columns | `np.column_stack((a, b))` |
| Shape | row_stack | Alias for vstack | `np.row_stack((a, b))` |
| Shape | concatenate | Join arrays along existing axis | `np.concatenate([a, b], axis=0)` |
| Shape | append | Append values to array | `np.append(a, [4, 5])` |
| Shape | tile | Repeat array | `np.tile(a, (2, 3))` |
| Shape | repeat | Repeat elements | `np.repeat(a, 3)` |
| Shape | repeat axis | Repeat along axis | `np.repeat(a, [1, 2], axis=0)` |
| Shape | split | Split into N sections | `np.split(a, 3)` |
| Shape | array_split | Split into N sub-arrays | `np.array_split(a, 3)` |
| Shape | hsplit | Horizontal split | `np.hsplit(a, 3)` |
| Shape | vsplit | Vertical split | `np.vsplit(a, 3)` |
| Shape | dsplit | Depth split | `np.dsplit(a, 3)` |
| Shape | resize | Resize in-place (fills with zeros) | `a.resize((2, 3))` |
| Shape | pad | Pad array with constant/edge values | `np.pad(a, pad_width=1, mode="constant")` |
| Shape | trim_zeros | Trim leading/trailing zeros | `np.trim_zeros(a)` |
| Shape | flip | Reverse along axis | `np.flip(a, axis=0)` |
| Shape | fliplr | Flip left-right | `np.fliplr(a)` |
| Shape | flipud | Flip up-down | `np.flipud(a)` |
| Shape | rot90 | Rotate 90 degrees | `np.rot90(a, k=1)` |
| Shape | roll | Roll elements along axis | `np.roll(a, shift=2, axis=0)` |

### 12. Linear Algebra (np.linalg)

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Linear Algebra | dot | Dot product | `np.dot(a, b)` |
| Linear Algebra | matmul / @ | Matrix multiplication | `a @ b` |
| Linear Algebra | vecdot | Vector dot along axis (NumPy 2.0) | `np.linalg.vecdot(a, b)` |
| Linear Algebra | matrix_power | Matrix to integer power | `np.linalg.matrix_power(a, 3)` |
| Linear Algebra | det | Determinant | `np.linalg.det(a)` |
| Linear Algebra | slogdet | Sign and log of determinant | `np.linalg.slogdet(a)` |
| Linear Algebra | inv | Matrix inverse | `np.linalg.inv(a)` |
| Linear Algebra | pinv | Moore-Penrose pseudoinverse | `np.linalg.pinv(a)` |
| Linear Algebra | solve | Solve linear system Ax = b | `np.linalg.solve(a, b)` |
| Linear Algebra | lstsq | Least-squares solution | `np.linalg.lstsq(a, b, rcond=None)` |
| Linear Algebra | eig | Eigenvalues and eigenvectors | `eigvals, eigvecs = np.linalg.eig(a)` |
| Linear Algebra | eigvals | Eigenvalues only | `np.linalg.eigvals(a)` |
| Linear Algebra | eigh | Hermitian eigen-decomposition | `np.linalg.eigh(a)` |
| Linear Algebra | eigvalsh | Hermitian eigenvalues | `np.linalg.eigvalsh(a)` |
| Linear Algebra | svd | Singular value decomposition | `U, S, Vh = np.linalg.svd(a)` |
| Linear Algebra | norm | Vector/matrix norm | `np.linalg.norm(a)` |
| Linear Algebra | norm ord | Specific norm (fro, nuc, 1, 2, inf) | `np.linalg.norm(a, ord="fro")` |
| Linear Algebra | vector_norm | Vector norm (NumPy 2.0) | `np.linalg.vector_norm(a, ord=2)` |
| Linear Algebra | matrix_norm | Matrix norm (NumPy 2.0) | `np.linalg.matrix_norm(a, ord="fro")` |
| Linear Algebra | cond | Condition number | `np.linalg.cond(a)` |
| Linear Algebra | matrix_rank | Matrix rank | `np.linalg.matrix_rank(a)` |
| Linear Algebra | qr | QR decomposition | `Q, R = np.linalg.qr(a)` |
| Linear Algebra | cholesky | Cholesky decomposition | `np.linalg.cholesky(a)` |
| Linear Algebra | tensorinv | Inverse of tensor | `np.linalg.tensorinv(a)` |
| Linear Algebra | tensorsolve | Solve tensor equation | `np.linalg.tensorsolve(a, b)` |
| Linear Algebra | cross | Cross product | `np.cross(a, b)` |
| Linear Algebra | outer | Outer product | `np.outer(a, b)` |
| Linear Algebra | inner | Inner product | `np.inner(a, b)` |
| Linear Algebra | kron | Kronecker product | `np.kron(a, b)` |
| Linear Algebra | multi_dot | Efficient multi-matrix dot | `np.linalg.multi_dot([a, b, c])` |

### 13. Random Sampling (np.random)

#### 13a. Legacy API (np.random.*)

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Random Legacy | rand | Uniform [0,1) | `np.random.rand(3, 3)` |
| Random Legacy | randn | Standard normal | `np.random.randn(3, 3)` |
| Random Legacy | randint | Random integers | `np.random.randint(0, 10, size=(3, 3))` |
| Random Legacy | random | Uniform [0,1) | `np.random.random((3, 3))` |
| Random Legacy | choice | Random sample from array | `np.random.choice(a, size=5, replace=False)` |
| Random Legacy | shuffle | Shuffle in-place | `np.random.shuffle(a)` |
| Random Legacy | permutation | Random permutation | `np.random.permutation(10)` |
| Random Legacy | normal | Normal distribution | `np.random.normal(loc=0, scale=1, size=100)` |
| Random Legacy | uniform | Uniform distribution | `np.random.uniform(low=0, high=1, size=100)` |
| Random Legacy | binomial | Binomial distribution | `np.random.binomial(n=10, p=0.5, size=100)` |
| Random Legacy | poisson | Poisson distribution | `np.random.poisson(lam=5, size=100)` |
| Random Legacy | exponential | Exponential distribution | `np.random.exponential(scale=1, size=100)` |
| Random Legacy | gamma | Gamma distribution | `np.random.gamma(shape=2, scale=1, size=100)` |
| Random Legacy | beta | Beta distribution | `np.random.beta(a=2, b=5, size=100)` |
| Random Legacy | seed | Set random seed | `np.random.seed(42)` |

#### 13b. Generator API (Modern, NumPy 1.17+)

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Random Modern | default_rng | Create Generator | `rng = np.random.default_rng(42)` |
| Random Modern | integers | Random integers | `rng.integers(0, 10, size=5)` |
| Random Modern | random | Uniform [0,1) | `rng.random((3, 3))` |
| Random Modern | standard_normal | Standard normal | `rng.standard_normal((3, 3))` |
| Random Modern | normal | Normal distribution | `rng.normal(loc=0, scale=1, size=100)` |
| Random Modern | uniform | Uniform distribution | `rng.uniform(0, 1, size=100)` |
| Random Modern | choice | Random choice | `rng.choice(a, size=5, replace=False)` |
| Random Modern | shuffle | Shuffle in-place | `rng.shuffle(a)` |
| Random Modern | permutation | Random permutation | `rng.permutation(10)` |
| Random Modern | permuted | Randomly permute along axis | `rng.permuted(a, axis=0)` |
| Random Modern | binomial | Binomial distribution | `rng.binomial(n=10, p=0.5, size=100)` |
| Random Modern | poisson | Poisson distribution | `rng.poisson(lam=5, size=100)` |
| Random Modern | exponential | Exponential distribution | `rng.exponential(scale=1, size=100)` |
| Random Modern | gamma | Gamma distribution | `rng.gamma(shape=2, scale=1, size=100)` |
| Random Modern | beta | Beta distribution | `rng.beta(a=2, b=5, size=100)` |
| Random Modern | multivariate_normal | Multivariate normal | `rng.multivariate_normal(mean, cov, size=100)` |
| Random Modern | PCG64 | Bit generator | `rng = np.random.Generator(np.random.PCG64(42))` |
| Random Modern | MT19937 | Mersenne Twister bit generator | `rng = np.random.Generator(np.random.MT19937(42))` |

### 14. Discrete Fourier Transforms (np.fft)

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| FFT | fft | 1D FFT | `np.fft.fft(a)` |
| FFT | ifft | 1D inverse FFT | `np.fft.ifft(a)` |
| FFT | fft2 | 2D FFT | `np.fft.fft2(a)` |
| FFT | ifft2 | 2D inverse FFT | `np.fft.ifft2(a)` |
| FFT | fftn | N-D FFT | `np.fft.fftn(a)` |
| FFT | ifftn | N-D inverse FFT | `np.fft.ifftn(a)` |
| FFT | rfft | Real-input FFT | `np.fft.rfft(a)` |
| FFT | irfft | Real-input inverse FFT | `np.fft.irfft(a)` |
| FFT | rfft2 | 2D real FFT | `np.fft.rfft2(a)` |
| FFT | irfft2 | 2D real inverse FFT | `np.fft.irfft2(a)` |
| FFT | rfftn | N-D real FFT | `np.fft.rfftn(a)` |
| FFT | irfftn | N-D real inverse FFT | `np.fft.irfftn(a)` |
| FFT | hfft | FFT of Hermitian-symmetric signal | `np.fft.hfft(a)` |
| FFT | ihfft | Inverse hfft | `np.fft.ihfft(a)` |
| FFT | fftfreq | FFT sample frequencies | `np.fft.fftfreq(n=100, d=0.01)` |
| FFT | rfftfreq | Real FFT sample frequencies | `np.fft.rfftfreq(n=100, d=0.01)` |
| FFT | fftshift | Shift zero-frequency to center | `np.fft.fftshift(a)` |
| FFT | ifftshift | Inverse of fftshift | `np.fft.ifftshift(a)` |

### 15. String Operations (np.strings / np.char)

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Strings | add | Concatenate strings | `np.strings.add(["a", "b"], ["c", "d"])` |
| Strings | multiply | Repeat strings | `np.strings.multiply(["a", "b"], [2, 3])` |
| Strings | mod | Format strings | `np.strings.mod(["%s-%d"], [("x", 1)])` |
| Strings | capitalize | Capitalize first letter | `np.strings.capitalize(["hello"])` |
| Strings | center | Center with padding | `np.strings.center(["hi"], 10)` |
| Strings | encode | Encode to bytes | `np.strings.encode(["hello"], "utf-8")` |
| Strings | decode | Decode from bytes | `np.strings.decode([b"hello"], "utf-8")` |
| Strings | join | Join strings with separator | `np.strings.join("-", ["a", "b", "c"])` |
| Strings | ljust | Left-justify | `np.strings.ljust(["hi"], 10)` |
| Strings | lower | Lowercase | `np.strings.lower(["HELLO"])` |
| Strings | lstrip | Strip left whitespace | `np.strings.lstrip(["  hello"])` |
| Strings | partition | Partition on separator | `np.strings.partition(["a-b"], "-")` |
| Strings | replace | Replace substring | `np.strings.replace(["hello"], "l", "z")` |
| Strings | rjust | Right-justify | `np.strings.rjust(["hi"], 10)` |
| Strings | rpartition | Right partition | `np.strings.rpartition(["a-b-c"], "-")` |
| Strings | rsplit | Split from right | `np.strings.rsplit(["a-b-c"], "-")` |
| Strings | rstrip | Strip right whitespace | `np.strings.rstrip(["hello  "])` |
| Strings | split | Split by separator | `np.strings.split(["a,b,c"], ",")` |
| Strings | splitlines | Split on line breaks | `np.strings.splitlines(["a\\nb"])` |
| Strings | strip | Strip whitespace | `np.strings.strip(["  hello  "])` |
| Strings | swapcase | Swap case | `np.strings.swapcase(["Hello"])` |
| Strings | title | Title case | `np.strings.title(["hello world"])` |
| Strings | translate | Character translation | `np.strings.translate(["hello"], str.maketrans("l", "z"))` |
| Strings | upper | Uppercase | `np.strings.upper(["hello"])` |
| Strings | zfill | Pad with zeros | `np.strings.zfill(["42"], 5)` |
| Strings | equal | Element-wise equality | `np.strings.equal(["a"], ["a"])` |
| Strings | not_equal | Element-wise inequality | `np.strings.not_equal(["a"], ["b"])` |
| Strings | greater | Lexicographic greater | `np.strings.greater(["b"], ["a"])` |
| Strings | greater_equal | Greater or equal | `np.strings.greater_equal(["a"], ["a"])` |
| Strings | less | Lexicographic less | `np.strings.less(["a"], ["b"])` |
| Strings | less_equal | Less or equal | `np.strings.less_equal(["a"], ["b"])` |
| Strings | count | Count occurrences | `np.strings.count(["hello"], "l")` |
| Strings | find | Find substring index | `np.strings.find(["hello"], "ll")` |
| Strings | rfind | Find from right | `np.strings.rfind(["hello"], "l")` |
| Strings | index | Find (raises if missing) | `np.strings.index(["hello"], "ll")` |
| Strings | rindex | Right index | `np.strings.rindex(["hello"], "l")` |
| Strings | isalpha | All alphabetic? | `np.strings.isalpha(["abc"])` |
| Strings | isdecimal | All decimal? | `np.strings.isdecimal(["123"])` |
| Strings | isdigit | All digits? | `np.strings.isdigit(["123"])` |
| Strings | islower | All lowercase? | `np.strings.islower(["abc"])` |
| Strings | isspace | All whitespace? | `np.strings.isspace(["  "])` |
| Strings | istitle | Title case? | `np.strings.istitle(["Hello World"])` |
| Strings | isupper | All uppercase? | `np.strings.isupper(["ABC"])` |
| Strings | startswith | Starts with prefix? | `np.strings.startswith(["hello"], "he")` |
| Strings | endswith | Ends with suffix? | `np.strings.endswith(["hello"], "lo")` |
| Strings | str_len | String length | `np.strings.str_len(["hello"])` |

### 16. Masked Arrays (np.ma)

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Masked Arrays | masked_array | Create masked array | `np.ma.masked_array(a, mask=[True, False, True])` |
| Masked Arrays | masked_where | Mask where condition True | `np.ma.masked_where(a < 0, a)` |
| Masked Arrays | masked_greater | Mask values > threshold | `np.ma.masked_greater(a, 5)` |
| Masked Arrays | masked_less | Mask values < threshold | `np.ma.masked_less(a, 0)` |
| Masked Arrays | masked_inside | Mask values in range | `np.ma.masked_inside(a, 1, 5)` |
| Masked Arrays | masked_outside | Mask values outside range | `np.ma.masked_outside(a, 1, 5)` |
| Masked Arrays | masked_invalid | Mask NaN and Inf | `np.ma.masked_invalid(a)` |
| Masked Arrays | masked_equal | Mask equal to value | `np.ma.masked_equal(a, 0)` |
| Masked Arrays | masked_not_equal | Mask not equal to value | `np.ma.masked_not_equal(a, 0)` |
| Masked Arrays | masked_values | Mask specific values | `np.ma.masked_values(a, 999)` |
| Masked Arrays | masked | Global masked constant | `np.ma.masked` |
| Masked Arrays | nomask | No mask constant | `np.ma.nomask` |
| Masked Arrays | filled | Fill masked values | `np.ma.filled(ma, fill_value=0)` |
| Masked Arrays | compress | Compress to non-masked | `np.ma.compress_rows(ma)` |
| Masked Arrays | fix_invalid | Fix invalid entries | `np.ma.fix_invalid(a)` |
| Masked Arrays | masked_all | Empty masked array | `np.ma.masked_all((3, 3))` |
| Masked Arrays | masked_all_like | Like another array | `np.ma.masked_all_like(a)` |
| Masked Arrays | getmask | Get mask array | `np.ma.getmask(ma)` |
| Masked Arrays | getmaskarray | Get mask as array | `np.ma.getmaskarray(ma)` |
| Masked Arrays | getdata | Get underlying data | `np.ma.getdata(ma)` |
| Masked Arrays | average | Average ignoring masked | `np.ma.average(ma)` |
| Masked Arrays | median | Median ignoring masked | `np.ma.median(ma)` |
| Masked Arrays | std | Std ignoring masked | `np.ma.std(ma)` |
| Masked Arrays | var | Variance ignoring masked | `np.ma.var(ma)` |
| Masked Arrays | sum | Sum ignoring masked | `np.ma.sum(ma)` |
| Masked Arrays | mean | Mean ignoring masked | `np.ma.mean(ma)` |
| Masked Arrays | min | Min ignoring masked | `np.ma.min(ma)` |
| Masked Arrays | max | Max ignoring masked | `np.ma.max(ma)` |
| Masked Arrays | argmin | Argmin ignoring masked | `np.ma.argmin(ma)` |
| Masked Arrays | argmax | Argmax ignoring masked | `np.ma.argmax(ma)` |
| Masked Arrays | count | Count non-masked | `np.ma.count(ma)` |
| Masked Arrays | cumsum | Cumsum ignoring masked | `np.ma.cumsum(ma)` |
| Masked Arrays | cumprod | Cumprod ignoring masked | `np.ma.cumprod(ma)` |
| Masked Arrays | masked_print_option | Control print format | `np.ma.masked_print_option.set_display("--")` |

### 17. Memory Layout & Views

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Memory | view | New view of same data | `b = a.view()` |
| Memory | view dtype | View with different dtype | `a.view(np.float32)` |
| Memory | copy | Deep copy of array | `b = a.copy()` |
| Memory | copy order | Copy with specific order | `a.copy(order="F")` |
| Memory | ascontiguousarray | Force C-contiguous | `np.ascontiguousarray(a)` |
| Memory | asfortranarray | Force Fortran-contiguous | `np.asfortranarray(a)` |
| Memory | require | Ensure requirements met | `np.require(a, requirements=["C", "A", "O"])` |
| Memory | share_memory | Check if arrays share memory | `np.shares_memory(a, b)` |
| Memory | may_share_memory | Check possible memory sharing | `np.may_share_memory(a, b)` |
| Memory | flags | Memory layout flags | `a.flags` |
| Memory | strides | Byte steps per dimension | `a.strides` |
| Memory | itemsize | Bytes per element | `a.itemsize` |
| Memory | nbytes | Total bytes | `a.nbytes` |
| Memory | base | Base object if view | `a.base` |
| Memory | data | Memory address | `a.data` |
| Memory | ctypes | C-compatible interface | `a.ctypes` |
| Memory | __array_interface__ | Protocol for sharing | `a.__array_interface__` |

### 18. Structured Arrays & Records

| Theme | Query | Explanation / Keywords | Syntax Example |
|---|---|---|---|
| Structured | dtype structured | Define structured dtype | `dt = np.dtype([("x", float), ("y", float), ("name", "U10")])` |
| Structured | recarray | Record array with field access | `ra = np.recarray(3, dtype=dt)` |
| Structured | fromarrays | Create from separate arrays | `np.rec.fromarrays([x, y, names], names=["x", "y", "name"])` |
| Structured | fromrecords | Create from records | `np.rec.fromrecords([(1, 2, "a")], names=["x", "y", "name"])` |
| Structured | array with dtype | Create structured array | `a = np.array([(1, 2, "a")], dtype=dt)` |
| Structured | field access | Access by field name | `a["x"]` or `a["name"]` |
| Structured | field assignment | Assign to field | `a["x"] = [10, 20, 30]` |
| Structured | field names | List field names | `a.dtype.names` |
| Structured | field types | Field data types | `a.dtype.fields` |
| Structured | view as recarray | View as record array | `a.view(np.recarray)` |
| Structured | sort by field | Sort by a field | `np.sort(a, order="x")` |
| Structured | argsort by field | Argsort by field | `np.argsort(a, order="x")` |
| Structured | unique by field | Unique by field | `np.unique(a["name"])` |

### 19. Polynomial Fitting (np.polynomial)
Fitting, evaluating, differentiating, integrating, finding roots of polynomials.


| theme | query | explanation | syntax example |
|---|---|---|---|
| Polynomial Fitting | `Polynomial()` | create polynomial from coefficients, low degree to high degree | `from numpy.polynomial import Polynomial; p = Polynomial([1, 2, 3])` |
| Polynomial Fitting | `Polynomial.fromroots()` | build polynomial from roots | `Polynomial.fromroots([-1, 1])` |
| Polynomial Fitting | `Polynomial.fit()` | fit polynomial to data, recommended modern API | `Polynomial.fit(x, y, deg=3)` |
| Polynomial Fitting | `p(x)` | evaluate polynomial at scalar or array | `p(x_vals)` |
| Polynomial Fitting | `p.convert()` | convert fitted polynomial to unscaled basis/domain | `p_fit.convert()` |
| Polynomial Fitting | `p.deriv()` | differentiate polynomial | `p.deriv()` |
| Polynomial Fitting | `p.integ()` | integrate polynomial | `p.integ()` |
| Polynomial Fitting | `p.roots()` | find polynomial roots | `p.roots()` |
| Polynomial Fitting | `np.polyfit()` | legacy polynomial fitting function | `np.polyfit(x, y, deg=2)` |
| Polynomial Fitting | `np.polyval()` | legacy polynomial evaluation | `np.polyval(coeffs, x)` |
| Polynomial Fitting | `np.roots()` | legacy root finding from coefficients | `np.roots(coeffs)` |


### 20. Histograms & Binning
Histogram, 2D histogram, N-D histogram, bincount, digitize.
| theme | query | explanation | syntax example |
|---|---|---|---|

| Histograms & Binning | `np.histogram()` | 1D histogram counts and bin edges | `hist, edges = np.histogram(x, bins=10)` |
| Histograms & Binning | `np.histogram(..., density=True)` | normalized density histogram | `hist, edges = np.histogram(x, bins=20, density=True)` |
| Histograms & Binning | `np.histogram(..., weights=...)` | weighted histogram | `hist, edges = np.histogram(x, bins=bins, weights=w)` |
| Histograms & Binning | `np.histogram2d()` | 2D histogram for paired variables | `hist2d, xedges, yedges = np.histogram2d(x, y, bins=20)` |
| Histograms & Binning | `np.histogramdd()` | N-dimensional histogram | `histdd, edges = np.histogramdd(data, bins=(10, 10, 10))` |
| Histograms & Binning | `np.bincount()` | count non-negative integer occurrences | `np.bincount(labels)` |
| Histograms & Binning | `np.bincount(..., weights=...)` | weighted counting by integer label | `np.bincount(labels, weights=values)` |
| Histograms & Binning | `np.digitize()` | assign values to bins by edge intervals | `bin_ids = np.digitize(x, bins)` |
| Histograms & Binning | `np.searchsorted()` | alternative bin lookup on sorted edges | `idx = np.searchsorted(edges, x, side='right')` |
| Histograms & Binning | `np.linspace()` | create equal-width bin edges | `bins = np.linspace(0, 100, 11)` |



### 21. Set Operations
Unique, intersection, union, difference, symmetric difference, membership testing.
| theme | query | explanation | syntax example |
|---|---|---|---|
| Set Operations | `np.unique()` | unique values, optional counts/indexes | `np.unique(arr)` |
| Set Operations | `np.unique(..., return_counts=True)` | unique values with frequencies | `vals, counts = np.unique(arr, return_counts=True)` |
| Set Operations | `np.intersect1d()` | sorted intersection of two arrays | `np.intersect1d(a, b)` |
| Set Operations | `np.union1d()` | sorted union of two arrays | `np.union1d(a, b)` |
| Set Operations | `np.setdiff1d()` | elements in one array not in another | `np.setdiff1d(a, b)` |
| Set Operations | `np.setxor1d()` | symmetric difference | `np.setxor1d(a, b)` |
| Set Operations | `np.isin()` | membership test elementwise | `np.isin(a, [1, 3, 5])` |
| Set Operations | `np.in1d()` | legacy-style 1D membership check | `np.in1d(a, b)` |

### 22. Testing & Assertions
Allclose, isclose, array_equal, array_equiv, and pytest-style assertions.
| theme | query | explanation | syntax example |
|---|---|---|---|

| Testing & Assertions | `np.allclose()` | arrays approximately equal within tolerance | `np.allclose(a, b, rtol=1e-5, atol=1e-8)` |
| Testing & Assertions | `np.isclose()` | elementwise approximate equality | `np.isclose(a, b)` |
| Testing & Assertions | `np.array_equal()` | exact same shape and values | `np.array_equal(a, b)` |
| Testing & Assertions | `np.array_equiv()` | shape-compatible exact equality | `np.array_equiv(a, b)` |
| Testing & Assertions | `np.testing.assert_allclose()` | pytest-style approximate assertion | `np.testing.assert_allclose(a, b)` |
| Testing & Assertions | `np.testing.assert_array_equal()` | pytest-style exact array assertion | `np.testing.assert_array_equal(a, b)` |
| Testing & Assertions | `np.testing.assert_array_almost_equal()` | decimal-based approximate assertion | `np.testing.assert_array_almost_equal(a, b, decimal=6)` |
| Testing & Assertions | `np.testing.assert_equal()` | exact assertion for scalars/arrays | `np.testing.assert_equal(actual, expected)` |
| Testing & Assertions | `np.testing.assert_raises()` | verify expected exception in tests | `with np.testing.assert_raises(ValueError): func()` |


### 23. Input/Output
Save, load, savez, memmap, text files, CSV, and binary I/O.
| theme | query | explanation | syntax example |
|---|---|---|---|

| Input/Output | `np.save()` | save one array to `.npy` binary file | `np.save('arr.npy', arr)` |
| Input/Output | `np.load()` | load `.npy` or `.npz` file | `arr = np.load('arr.npy')` |
| Input/Output | `np.savez()` | save multiple arrays in one `.npz` archive | `np.savez('data.npz', x=x, y=y)` |
| Input/Output | `np.savez_compressed()` | compressed `.npz` archive | `np.savez_compressed('data.npz', x=x, y=y)` |
| Input/Output | `np.memmap()` | memory-mapped array for large files | `mm = np.memmap('big.dat', dtype='float32', mode='r', shape=(1000, 1000))` |
| Input/Output | `np.savetxt()` | save array to text file | `np.savetxt('data.txt', arr)` |
| Input/Output | `np.loadtxt()` | load numeric text file | `arr = np.loadtxt('data.txt')` |
| Input/Output | `np.genfromtxt()` | load text with missing values/headers | `arr = np.genfromtxt('data.csv', delimiter=',', skip_header=1)` |
| Input/Output | `ndarray.tofile()` | write raw binary or text stream | `arr.tofile('raw.bin')` |
| Input/Output | `np.fromfile()` | read raw binary/text into array | `arr = np.fromfile('raw.bin', dtype=np.float64)` |
| Input/Output | `np.frombuffer()` | create array view from buffer object | `arr = np.frombuffer(buf, dtype=np.uint8)` |


### 24. NumPy 2.0 Modern Features
StringDType, copy keyword changes, cumulative_sum, vecdot, matrix_norm, vector_norm, array_api namespace.
| theme | query | explanation | syntax example |
|---|---|---|---|

| NumPy 2.0 Modern Features | `np.dtypes.StringDType()` | variable-length string dtype | `dt = np.dtypes.StringDType()` |
| NumPy 2.0 Modern Features | `dtype=StringDType()` | create array with modern string dtype | `arr = np.array(['a', 'bb'], dtype=np.dtypes.StringDType())` |
| NumPy 2.0 Modern Features | `copy=` keyword changes | stricter copy semantics in array creation/conversion | `np.array(obj, copy=False)` |
| NumPy 2.0 Modern Features | `np.cumulative_sum()` | Array API-style cumulative sum | `np.cumulative_sum(arr)` |
| NumPy 2.0 Modern Features | `np.vecdot()` | vector dot product across axes | `np.vecdot(a, b)` |
| NumPy 2.0 Modern Features | `np.linalg.vector_norm()` | explicit vector norm function | `np.linalg.vector_norm(x)` |
| NumPy 2.0 Modern Features | `np.linalg.matrix_norm()` | explicit matrix norm function | `np.linalg.matrix_norm(A)` |
| NumPy 2.0 Modern Features | `np.array_api` / array-API aligned usage | standardized array operations style | `# use array-API compatible patterns where supported` |
| NumPy 2.0 Modern Features | `np.strings` | string operations namespace for modern string dtype | `np.strings.lower(arr)` |
